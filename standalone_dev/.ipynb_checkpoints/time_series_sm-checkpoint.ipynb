# %%
import itertools
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")

import statsmodels.api as sm
from tools import progbar

# %%
# File created: Jan. 5 2019
# Tutorial Reference
# https://towardsdatascience.com/an-end-to-end-project-on-time-series-analysis-and-forecasting-with-python-4835e6bf050b

# %%
# Dataset:
# Consumer Price Index for All Urban Consumers: All Items
# Citation:
# U.S. Bureau of Labor Statistics, Consumer Price Index for All Urban Consumers: All Items [CPIAUCSL], 
# retrieved from FRED, Federal Reserve Bank of St. Louis;
# https://fred.stlouisfed.org/series/CPIAUCSL, January 4, 2019.

# %%
import datetime
# Timeit module.
def timeit(method):
    def timed(*args, **kw):
        ts = datetime.datetime.now()
        result = method(*args, **kw)
        te = datetime.datetime.now()
        print(f"Time: {te - ts}")
        return result
    return timed

# %%
df = pd.read_csv("./data/UNRATE.csv", index_col=0, parse_dates=True)
# df["DATE"] = pd.to_datetime(df["DATE"])
df.columns = ["UNRATE"]
print(df.dtypes)
df.head()
# month_df = df.resample("M").mean().head()
# Out:
# UNRATE    float64
# dtype: object
#             UNRATE
# DATE
# 1948-01-01     3.4
# 1948-02-01     3.8
# 1948-03-01     4.0
# 1948-04-01     3.9
# 1948-05-01     3.5

# %%
# 1st order differencing.
d1 = df.diff()
d1.dropna(inplace=True)
d1.head()
# Out:
#             UNRATE
# DATE
# 1948-02-01     0.4
# 1948-03-01     0.2
# 1948-04-01    -0.1
# 1948-05-01    -0.4
# 1948-06-01     0.1

# %%
df.plot(figsize=(18, 3), grid=True)
plt.title("Raw")
plt.show()
d1.plot(figsize=(18, 3), grid=True)
plt.title("1st differenced")
plt.show()

# %%
from pylab import rcParams
rcParams["figure.figsize"] = (18, 8)
rcParams["axes.grid"] = True
decomposition = sm.tsa.seasonal_decompose(df, model="additive")
fig = decomposition.plot()
plt.show()

# %%
# Grid Searching for Parameters
# Seasonal AutoRegressive Integrated Moving Average with eXogenous regressors model
p = d = q = range(2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [
    (x[0], x[1], x[2], 12)
    for x in list(itertools.product(p, d, q))
]

candidates = list()

for param in pdq:
    for param_seasonal in seasonal_pdq:
        model = sm.tsa.statespace.SARIMAX(
            df,
            order=param,
            seasonal_order=param_seasonal,
            enforce_stationarity=False,
            enforce_invertibility=False,
            freq="MS"
        )
        results = model.fit()
        candidates.append({
            "pdq": param,
            "seasonal_pdq": param_seasonal,
            "aic":results.aic
        })
        print(f"ARIMA{param}x{param_seasonal} - AIC:{results.aic}")
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12) - AIC:5464.770184245417
# ARIMA(0, 0, 0)x(0, 0, 1, 12) - AIC:4439.90930114837
# ARIMA(0, 0, 0)x(0, 1, 0, 12) - AIC:2683.3404004578333
# ARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC:2602.296462725237
# ARIMA(0, 0, 0)x(1, 0, 0, 12) - AIC:2679.9423681686003
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(0, 0, 0)x(1, 0, 1, 12) - AIC:2678.6224998813577
# ARIMA(0, 0, 0)x(1, 1, 0, 12) - AIC:2608.0204433540903
# ARIMA(0, 0, 0)x(1, 1, 1, 12) - AIC:2590.99097712614
# ARIMA(0, 0, 1)x(0, 0, 0, 12) - AIC:4305.604430265361
# ARIMA(0, 0, 1)x(0, 0, 1, 12) - AIC:3350.8743159222577
# ARIMA(0, 0, 1)x(0, 1, 0, 12) - AIC:1785.9761813759044
# ARIMA(0, 0, 1)x(0, 1, 1, 12) - AIC:1708.8252282539247
# ARIMA(0, 0, 1)x(1, 0, 0, 12) - AIC:1781.3633366980575
# ARIMA(0, 0, 1)x(1, 0, 1, 12) - AIC:1775.270566464893
# ARIMA(0, 0, 1)x(1, 1, 0, 12) - AIC:1726.9536176009806
# ARIMA(0, 0, 1)x(1, 1, 1, 12) - AIC:1709.7257066592947
# ARIMA(0, 1, 0)x(0, 0, 0, 12) - AIC:-250.66463354169184
# ARIMA(0, 1, 0)x(0, 0, 1, 12) - AIC:-278.1482055118489
# ARIMA(0, 1, 0)x(0, 1, 0, 12) - AIC:457.8430612596139
# ARIMA(0, 1, 0)x(0, 1, 1, 12) - AIC:-254.30315726609894
# ARIMA(0, 1, 0)x(1, 0, 0, 12) - AIC:-264.4335427134106
# ARIMA(0, 1, 0)x(1, 0, 1, 12) - AIC:-338.54165243663635
# ARIMA(0, 1, 0)x(1, 1, 0, 12) - AIC:129.03039731844123
# ARIMA(0, 1, 0)x(1, 1, 1, 12) - AIC:-200.0275550166167
# ARIMA(0, 1, 1)x(0, 0, 0, 12) - AIC:-255.72328650169942
# ARIMA(0, 1, 1)x(0, 0, 1, 12) - AIC:-284.8938404709672
# ARIMA(0, 1, 1)x(0, 1, 0, 12) - AIC:455.0923485293134
# ARIMA(0, 1, 1)x(0, 1, 1, 12) - AIC:-268.3860229103872
# ARIMA(0, 1, 1)x(1, 0, 0, 12) - AIC:-270.3485338465943
# ARIMA(0, 1, 1)x(1, 0, 1, 12) - AIC:-349.7528687033905
# ARIMA(0, 1, 1)x(1, 1, 0, 12) - AIC:116.8588696373446
# ARIMA(0, 1, 1)x(1, 1, 1, 12) - AIC:-206.71996595991257
# ARIMA(1, 0, 0)x(0, 0, 0, 12) - AIC:-246.49758343538292
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(1, 0, 0)x(0, 0, 1, 12) - AIC:-239.53472539059163
# ARIMA(1, 0, 0)x(0, 1, 0, 12) - AIC:444.2162110790526
# ARIMA(1, 0, 0)x(0, 1, 1, 12) - AIC:-253.10104023033682
# ARIMA(1, 0, 0)x(1, 0, 0, 12) - AIC:-262.6507012374916
# ARIMA(1, 0, 0)x(1, 0, 1, 12) - AIC:-271.366054701206
# ARIMA(1, 0, 0)x(1, 1, 0, 12) - AIC:120.87146723695496
# ARIMA(1, 0, 0)x(1, 1, 1, 12) - AIC:-198.21822658907837
# ARIMA(1, 0, 1)x(0, 0, 0, 12) - AIC:-254.38241061901374
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(1, 0, 1)x(0, 0, 1, 12) - AIC:-245.91453148857528
# ARIMA(1, 0, 1)x(0, 1, 0, 12) - AIC:439.6049588587298
# ARIMA(1, 0, 1)x(0, 1, 1, 12) - AIC:-269.68453300744284
# ARIMA(1, 0, 1)x(1, 0, 0, 12) - AIC:-268.5875014920668
# ARIMA(1, 0, 1)x(1, 0, 1, 12) - AIC:-281.7034370955659
# ARIMA(1, 0, 1)x(1, 1, 0, 12) - AIC:106.99290214428142
# ARIMA(1, 0, 1)x(1, 1, 1, 12) - AIC:-206.67380369660617
# ARIMA(1, 1, 0)x(0, 0, 0, 12) - AIC:-260.47613524451424
# ARIMA(1, 1, 0)x(0, 0, 1, 12) - AIC:-289.7541010432937
# ARIMA(1, 1, 0)x(0, 1, 0, 12) - AIC:451.8334174129506
# ARIMA(1, 1, 0)x(0, 1, 1, 12) - AIC:-275.2439847026985
# ARIMA(1, 1, 0)x(1, 0, 0, 12) - AIC:-278.3007811236659
# ARIMA(1, 1, 0)x(1, 0, 1, 12) - AIC:-356.0000439000342
# ARIMA(1, 1, 0)x(1, 1, 0, 12) - AIC:106.13107378139566
# ARIMA(1, 1, 0)x(1, 1, 1, 12) - AIC:-210.17379244870443
# ARIMA(1, 1, 1)x(0, 0, 0, 12) - AIC:-323.03662741264634
# ARIMA(1, 1, 1)x(0, 0, 1, 12) - AIC:-372.00666616736265
# ARIMA(1, 1, 1)x(0, 1, 0, 12) - AIC:400.2587787447096
# ARIMA(1, 1, 1)x(0, 1, 1, 12) - AIC:-344.2036231680689
# ARIMA(1, 1, 1)x(1, 0, 0, 12) - AIC:-357.5058093101275
# ARIMA(1, 1, 1)x(1, 0, 1, 12) - AIC:-432.30740192616753
# ARIMA(1, 1, 1)x(1, 1, 0, 12) - AIC:35.68350519705166
# ARIMA(1, 1, 1)x(1, 1, 1, 12) - AIC:-289.9776608468522

# %%
# # Grid Searching for Parameters
# p = q = range(10)
# d = [1]
# pdq_set = tuple(itertools.product(p, d, q))
# candidates = list()

# for (i, param) in enumerate(pdq_set):
#     progbar(i+1, len(pdq_set), max(len(pdq_set), 30))
#     try:
#         model = sm.tsa.statespace.SARIMAX(
#             df,
#             order=param,
#             enforce_stationarity=False,
#             enforce_invertibility=False,
#             freq="MS"
#         )
#         results = model.fit()
#         candidates.append({
#             "pdq": param,
#             "aic": results.aic
#         })
# #         print(f"ARIMA{param} - AIC:{results.aic}")
#     except:
#         continue

# %%
candidates.sort(key=lambda x:x["aic"])
from pprint import pprint
pprint(candidates[:5])
best_pdq, best_spdq = candidates[0]["pdq"], candidates[0]["seasonal_pdq"]
# Out:
# [{'aic': -432.30740192616753, 'pdq': (1, 1, 1), 'seasonal_pdq': (1, 0, 1, 12)},
#  {'aic': -372.00666616736265, 'pdq': (1, 1, 1), 'seasonal_pdq': (0, 0, 1, 12)},
#  {'aic': -357.5058093101275, 'pdq': (1, 1, 1), 'seasonal_pdq': (1, 0, 0, 12)},
#  {'aic': -356.0000439000342, 'pdq': (1, 1, 0), 'seasonal_pdq': (1, 0, 1, 12)},
#  {'aic': -349.7528687033905, 'pdq': (0, 1, 1), 'seasonal_pdq': (1, 0, 1, 12)}]

# %%
# Fitting Seasonal ARIMA
model = sm.tsa.statespace.SARIMAX(
    df,
    order=best_pdq,
    seasonal_order=best_spdq,
    enforce_stationarity=False,
    enforce_invertibility=False,
    freq="MS"
)

results = model.fit()

# %%
# print(results.summary())

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime("2000-01-01"), dynamic=False)
pred_ci = pred.conf_int()
pred_ci.columns
# Out:
# Index(['lower UNRATE', 'upper UNRATE'], dtype='object')

# %%
rcParams["figure.figsize"] = (24, 8)
ax = df[pd.to_datetime("2000-01-01"):].plot(label="observed", alpha=.7)
pred.predicted_mean.plot(ax=ax, label="One-step ahead Forecast", alpha=.7)
ax.fill_between(
    pred_ci.index,
    pred_ci["lower UNRATE"],
    pred_ci["upper UNRATE"],
    color="green",
    alpha=.2,
    label="Confidence Interval"
)
ax.set_xlabel("Date")
ax.set_ylabel("UNRATE Raw Value")
plt.title("ARIMA Prediction")
plt.legend()
plt.show()

# %%
predicted = pred.predicted_mean.values
observed = np.squeeze(df["2000-01-01":].values)
rmse = np.sqrt(np.mean(
    (predicted - observed) ** 2
))
print(rmse)
# Out:
# 0.13654635093515705

# %%
# Forecasting
alpha = 0.05
pred_uc = results.get_forecast(steps=24)
pred_ci = pred_uc.conf_int(alpha=alpha)

ax = df["2008-01-01":].plot(
    label="observed", figsize=(14, 7)
)
pred_uc.predicted_mean.plot(ax=ax, label="forecast")
ax.fill_between(
    pred_ci.index,
    pred_ci.iloc[:, 0],  # Lower CI
    pred_ci.iloc[:, 1],  # Upper CI
    color="green",
    alpha=0.2,
    label=f"{1-alpha} Conf Interval"
)
ax.set_xlabel("Date")
ax.set_ylabel("CPI")

plt.legend()
plt.show()
