# %%
"""
The default hyper-parameter searching program.
This is a control script.
"""
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint
from typing import Dict, List

import sys
sys.path.append(".../")
sys.path.append("../")

import constants
from core.tools.metrics import *
import core.tools.visualize as visualize
from core.tools.time_series import *
from core.tools.data_import import *
import core.tools.rnn_prepare as rnn_prepare

import core.models.stacked_lstm as stacked_lstm

import core.training.hps_methods as hps_methods

# data preparation phase.
pprint(constants.DATA_DIR)
choice = None
while choice is None or choice not in constants.DATA_DIR.keys():
    if choice is not None:
        print("Invalid data location received, try again...")
    choice = input("Select Dataset >>> ")
FILE_DIR = constants.DATA_DIR[choice]

print(f"Dataset chosen: \n\t{FILE_DIR}")

config_name = input("Name of configuration file to load >>> ")

exec(f"import core.training.configs.{config_name} as config")

for att in dir(config):
    if att.endswith("_config"):
        print(f"Loading: {att}")
        exec(f"globals().update(config.{att})")


parameter_collection = hps_methods.gen_hparam_set(config.train_param)


def individual_train(para) -> None:
    prepared_df = rnn_prepare.prepare_dataset(
        file_dir=FILE_DIR,
        periods=PERIODS,
        order=ORDER,
        remove=None
    )
    (X_train, X_val, X_test,
     y_train, y_val, y_test) = rnn_prepare.generate_splited_dataset(
        raw=prepared_df,
        train_ratio=0.8,
        val_ratio=0.1,
        lags=para["num_time_steps"]
    )
    data_collection = {
        "X_train": X_train,
        "X_val": X_val,
        "X_test": X_test,
        "y_train": y_train,
        "y_val": y_val,
        "y_test": y_test
    }

    def checkpoints(z): return [
        z*x for x in range(1, para["epochs"] // z)] + [-1]
    
    (metrics_dict, predictions) = stacked_lstm.exec_core(
        parameters=para,
        data_collection=data_collection,
        clip_grad=None,
        prediction_checkpoints=checkpoints(
            para["epochs"] // 10
        )
    )

    fig = visualize.plot_checkpoints(predictions, y_test, "test")
    plt.savefig(para["fig_path"]+"pred_records.svg")


for (i, para) in enumerate(parameter_collection):
    print(f"Control: executing [{i}]-th hyper-parameter searching session...")
    individual_train(para)
# Out:
# {'0': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv',
#  '1': '/home/ec2-user/AnnEconForecast/data/UNRATE.csv',
#  '2': '/home/ubuntu/AnnEconForecast/data/UNRATE.csv',
#  '3': '/home/ec2-user/AnnEconForecast/data/DEXCAUS.csv'}
# Select Dataset >>> 1
# Dataset chosen:
# 	/home/ec2-user/AnnEconForecast/data/UNRATE.csv
# Name of configuration file to load >>> sample_config
# Loading: dp_config
# Loading: file_config
# Total number of parameter sets generated: 18
# Control: executing [0]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 10459.6308594; Validation MSE 10682.9814453
#
# Iteration [100], Training MSE 1.0294645; Validation MSE 0.7934918
#
# Iteration [200], Training MSE 0.9926140; Validation MSE 0.7881114
# Saving the trained model...
# Time taken for [300] epochs:  0:00:16.653313
# Loss Summary:
# 	mae=0.5268462300300598
# 	mse=0.4517022967338562
# 	rmse=0.6720880270004272
# 	mape=3.50447154045105
# Control: executing [1]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 883.8627319; Validation MSE 802.4948730
#
# Iteration [100], Training MSE 0.6927647; Validation MSE 0.8576738
#
# Iteration [200], Training MSE 0.5690960; Validation MSE 0.9524782
# Saving the trained model...
# Time taken for [300] epochs:  0:00:12.456773
# Loss Summary:
# 	mae=0.5770519971847534
# 	mse=0.5455700159072876
# 	rmse=0.7386271357536316
# 	mape=8.251365661621094
# Control: executing [2]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 956.6704712; Validation MSE 1097.7369385
#
# Iteration [100], Training MSE 0.9690463; Validation MSE 0.7999535
#
# Iteration [200], Training MSE 0.9573442; Validation MSE 0.7934030
# Saving the trained model...
# Time taken for [300] epochs:  0:00:12.365287
# Loss Summary:
# 	mae=0.523362934589386
# 	mse=0.4360964596271515
# 	rmse=0.6603760123252869
# 	mape=3.9335315227508545
# Control: executing [3]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 69655.6640625; Validation MSE 69387.5781250
#
# Iteration [100], Training MSE 0.8924046; Validation MSE 0.7392491
#
# Iteration [200], Training MSE 0.6901594; Validation MSE 0.7580213
# Saving the trained model...
# Time taken for [300] epochs:  0:00:14.965844
# Loss Summary:
# 	mae=0.5396170616149902
# 	mse=0.47054019570350647
# 	rmse=0.6859593391418457
# 	mape=8.41633415222168
# Control: executing [4]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 2326.3867188; Validation MSE 3326.0832520
#
# Iteration [100], Training MSE 0.8738350; Validation MSE 0.7957176
#
# Iteration [200], Training MSE 1.1610315; Validation MSE 0.9280853
# Saving the trained model...
# Time taken for [300] epochs:  0:00:14.991987
# Loss Summary:
# 	mae=0.5396990776062012
# 	mse=0.4858759045600891
# 	rmse=0.697048008441925
# 	mape=3.9917798042297363
# Control: executing [5]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 4252.8872070; Validation MSE 4081.3847656
#
# Iteration [100], Training MSE 0.9296477; Validation MSE 0.7535866
#
# Iteration [200], Training MSE 0.7945510; Validation MSE 0.6376170
# Saving the trained model...
# Time taken for [300] epochs:  0:00:14.931107
# Loss Summary:
# 	mae=0.5291463732719421
# 	mse=0.4738026261329651
# 	rmse=0.6883332133293152
# 	mape=4.554305076599121
# Control: executing [6]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 5890.2534180; Validation MSE 5928.2851562
#
# Iteration [100], Training MSE 1.0566374; Validation MSE 0.8639736
#
# Iteration [200], Training MSE 0.7082400; Validation MSE 0.7768003
# Saving the trained model...
# Time taken for [300] epochs:  0:00:27.488961
# Loss Summary:
# 	mae=0.5090019702911377
# 	mse=0.37603917717933655
# 	rmse=0.6132203340530396
# 	mape=8.120840072631836
# Control: executing [7]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 95198.0703125; Validation MSE 94744.4218750
#
# Iteration [100], Training MSE 0.4790196; Validation MSE 1.0852287
#
# Iteration [200], Training MSE 0.2468627; Validation MSE 0.7353135
# Saving the trained model...
# Time taken for [300] epochs:  0:00:27.489729
# Loss Summary:
# 	mae=0.6572524309158325
# 	mse=0.6909790635108948
# 	rmse=0.8312515020370483
# 	mape=10.611409187316895
# Control: executing [8]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 29646.0957031; Validation MSE 22486.9960938
#
# Iteration [100], Training MSE 0.9509816; Validation MSE 0.7938260
#
# Iteration [200], Training MSE 0.9131919; Validation MSE 0.7859762
# Saving the trained model...
# Time taken for [300] epochs:  0:00:27.391078
# Loss Summary:
# 	mae=0.5386336445808411
# 	mse=0.47017616033554077
# 	rmse=0.6856939196586609
# 	mape=3.6090517044067383
# Control: executing [9]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 1092.7377930; Validation MSE 993.8563843
#
# Iteration [100], Training MSE 0.7478267; Validation MSE 0.8367006
#
# Iteration [200], Training MSE 0.6736656; Validation MSE 0.8409359
# Saving the trained model...
# Time taken for [300] epochs:  0:00:21.947874
# Loss Summary:
# 	mae=0.5587758421897888
# 	mse=0.5285553336143494
# 	rmse=0.7270181179046631
# 	mape=4.831137657165527
# Control: executing [10]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 12385.7285156; Validation MSE 11827.3173828
#
# Iteration [100], Training MSE 0.6840476; Validation MSE 0.6673904
#
# Iteration [200], Training MSE 0.6006162; Validation MSE 0.5660812
# Saving the trained model...
# Time taken for [300] epochs:  0:00:21.670012
# Loss Summary:
# 	mae=0.5263698697090149
# 	mse=0.45911261439323425
# 	rmse=0.6775785088539124
# 	mape=5.091737747192383
# Control: executing [11]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 600.4437866; Validation MSE 833.7735596
#
# Iteration [100], Training MSE 0.8064181; Validation MSE 0.7093303
#
# Iteration [200], Training MSE 0.7941189; Validation MSE 0.7181547
# Saving the trained model...
# Time taken for [300] epochs:  0:00:21.707721
# Loss Summary:
# 	mae=0.5237528085708618
# 	mse=0.47762686014175415
# 	rmse=0.6911055445671082
# 	mape=2.957524061203003
# Control: executing [12]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 185153.8437500; Validation MSE 185109.0156250
#
# Iteration [100], Training MSE 0.8469284; Validation MSE 0.9015935
#
# Iteration [200], Training MSE 0.4856355; Validation MSE 0.6471198
# Saving the trained model...
# Time taken for [300] epochs:  0:00:26.647857
# Loss Summary:
# 	mae=0.6898950934410095
# 	mse=0.778400719165802
# 	rmse=0.8822702169418335
# 	mape=8.573343276977539
# Control: executing [13]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 11951.6806641; Validation MSE 12088.9257812
#
# Iteration [100], Training MSE 0.8896775; Validation MSE 0.7802652
#
# Iteration [200], Training MSE 0.6796207; Validation MSE 0.7353533
# Saving the trained model...
# Time taken for [300] epochs:  0:00:26.666564
# Loss Summary:
# 	mae=0.6020432710647583
# 	mse=0.5974212884902954
# 	rmse=0.7729303240776062
# 	mape=5.531039237976074
# Control: executing [14]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 14879.5410156; Validation MSE 12219.1777344
#
# Iteration [100], Training MSE 0.8244864; Validation MSE 0.7055872
#
# Iteration [200], Training MSE 0.7998786; Validation MSE 0.7239985
# Saving the trained model...
# Time taken for [300] epochs:  0:00:26.600620
# Loss Summary:
# 	mae=0.5225896835327148
# 	mse=0.4776168763637543
# 	rmse=0.6910983324050903
# 	mape=2.7992968559265137
# Control: executing [15]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 896403.3750000; Validation MSE 891745.8125000
#
# Iteration [100], Training MSE 0.9764331; Validation MSE 0.7495907
#
# Iteration [200], Training MSE 0.7639775; Validation MSE 0.7895786
# Saving the trained model...
# Time taken for [300] epochs:  0:00:51.174061
# Loss Summary:
# 	mae=0.5286058187484741
# 	mse=0.47233471274375916
# 	rmse=0.6872661113739014
# 	mape=2.877436876296997
# Control: executing [16]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 138289.4062500; Validation MSE 138046.1718750
#
# Iteration [100], Training MSE 0.7711332; Validation MSE 0.7863693
#
# Iteration [200], Training MSE 0.7420860; Validation MSE 0.8024926
# Saving the trained model...
# Time taken for [300] epochs:  0:00:51.085142
# Loss Summary:
# 	mae=0.5115910172462463
# 	mse=0.4373314082622528
# 	rmse=0.6613103747367859
# 	mape=2.8326032161712646
# Control: executing [17]-th hyper-parameter searching session...
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1
# StandardScaler applied, scaling based on the first 679 observations.
# Total 824 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (824, 24, 1), y shape = (824, 1, 1)
# Training and testing set generated,
# X_train shape: (658, 24, 1)
# y_train shape: (658, 1)
# X_test shape: (83, 24, 1)
# y_test shape: (83, 1)
# X_validation shape: (83, 24, 1)
# y_validation shape: (83, 1)
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 84034.1328125; Validation MSE 83258.7109375
#
# Iteration [100], Training MSE 0.7963315; Validation MSE 0.7333406
