# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint
from typing import Dict

# %%
import sys
sys.path.append("../")

# %%
import constants
from core.tools.metrics import *
from core.tools.visualize import *
from core.tools.time_series import *
from core.tools.data_import import *
import core.tools.rnn_prepare as rnn_prepare

# %%
# Load the model
import core.models.stacked_lstm as stacked_lstm

# %%
# Avaiable datasets, loaded from constants.
pprint(constants.DATA_DIR)
choice = None
while choice is None or choice not in constants.DATA_DIR.keys():
    if choice is not None:
        print("Invalid data location received, try again...")
    choice = input("Select Dataset >>> ")
FILE_DIR = constants.DATA_DIR[choice]
# Out:
# {'0': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv',
#  '1': '/home/ec2-user/AnnEconForecast/data/UNRATE.csv',
#  '2': '/home/ubuntu/AnnEconForecast/data/UNRATE.csv',
#  '3': '/home/ec2-user/AnnEconForecast/data/DEXCAUS.csv'}
# Select Dataset >>> 1

# %%
print(f"Dataset chosen: \n{FILE_DIR}")
# Out:
# Dataset chosen:
# /home/ec2-user/AnnEconForecast/data/UNRATE.csv

# %%
# Pre-processing Parameters
PERIODS = 1
ORDER = 1
LAGS = 12
TRAIN_RATIO = 0.8

# %%
# # Neural Network Parameters
# NUM_TIME_STEPS = LAGS
# # Number of series used to predict. (including concurrent)
# NUM_INPUTS = 1
# NUM_OUTPUTS = 1
# NUM_NEURONS = 64
# # Number of output series
# LEARNING_RATE = 0.01
# EPOCHS = 50
# # Training Settings
# REPORT_PERIODS = 1
# TENSORBOARD_DIR = "./tensorboard/test/1"

# %%
EXPERIMENT_NAME = "local-demo"
TENSORBOARD_DIR = f"../tensorboard/{EXPERIMENT_NAME}"
MODEL_PATH = f"/home/ec2-user/saved_models/{EXPERIMENT_NAME}"

# %%
# Main Training Parameters
parameters = {
    "epochs": 10000,
    "num_time_steps": LAGS,
    "num_inputs": 1,
    "num_outputs": 1,
    "num_neurons": (512, 256, 128),
    "learning_rate": 0.1,
    "report_periods": 10,
    "tensorboard_dir": TENSORBOARD_DIR,
    "model_path": MODEL_PATH
}

# %%
prepared_df = rnn_prepare.prepare_dataset(
    file_dir=FILE_DIR,
    periods=PERIODS,
    order=ORDER
)
# Out:
# Retrieving raw data from /home/ec2-user/AnnEconForecast/data/UNRATE.csv...
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# Processing data, taking (periods, order)=(1, 1)...
# Dropping Nan observations...
# First few rows of dataset loaded:
#             UNRATE_period1_order1
# DATE
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# 1948-06-01                    0.1

# %%
# Normalize data
(X_train, X_val, X_test,
 y_train, y_val, y_test) = rnn_prepare.generate_splited_dataset(
    raw=prepared_df,
    train_ratio=0.8,
    val_ratio=0.1,
    lags=LAGS
)
# Out:
# StandardScaler applied, scaling based on the first 679 observations.
# Total 836 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (836, 12, 1), y shape = (836, 1, 1)
# Training and testing set generated,
# X_train shape: (668, 12, 1)
# y_train shape: (668, 1)
# X_test shape: (84, 12, 1)
# y_test shape: (84, 1)
# X_validation shape: (84, 12, 1)
# y_validation shape: (84, 1)

# %%
data_collection = {
    "X_train": X_train,
    "X_val": X_val,
    "X_test": X_test,
    "y_train": y_train,
    "y_val": y_val,
    "y_test": y_test
}

# %%
checkpoints = lambda z: [z*x for x in range(1, parameters["epochs"] // z)] + [-1]

# %%
# Run the model
(metrics_dict, predictions) = stacked_lstm.exec_core(
    parameters=parameters,
    data_collection=data_collection,
    clip_grad=None,
    prediction_checkpoints=checkpoints(200)
)
# Out:
# Resetting Tensorflow defalut graph...
# Note: no gradient clipping is applied.
# If possible gradient exploding detected (e.g. nan loss), try use clip_grad.
#
# Iteration [0], Training MSE 14263.2871094; Validation MSE 14897.7382812
#
# Iteration [100], Training MSE 0.9826497; Validation MSE 0.8143085
#
# Iteration [200], Training MSE 0.9807284; Validation MSE 0.7968675
#
# Iteration [300], Training MSE 0.9749871; Validation MSE 0.7891429
#
# Iteration [400], Training MSE 0.9685596; Validation MSE 0.7881277
#
# Iteration [500], Training MSE 0.9698730; Validation MSE 0.7916806
#
# Iteration [600], Training MSE 0.9691416; Validation MSE 0.7889012
#
# Iteration [700], Training MSE 0.9730799; Validation MSE 0.7916028
#
# Iteration [800], Training MSE 0.9662793; Validation MSE 0.7885198
#
# Iteration [900], Training MSE 1.1760651; Validation MSE 0.7983885
#
# Iteration [1000], Training MSE 0.9648532; Validation MSE 0.7863207
#
# Iteration [1100], Training MSE 0.9678211; Validation MSE 0.7694988
#
# Iteration [1200], Training MSE 0.9674686; Validation MSE 0.8631914
#
# Iteration [1300], Training MSE 0.9592556; Validation MSE 0.7857214
#
# Iteration [1400], Training MSE 0.9643214; Validation MSE 0.7807341
#
# Iteration [1500], Training MSE 1.2873294; Validation MSE 0.8711998
#
# Iteration [1600], Training MSE 1.9595062; Validation MSE 1.3880275
#
# Iteration [1700], Training MSE 0.9885331; Validation MSE 0.9099796
#
# Iteration [1800], Training MSE 0.9887663; Validation MSE 0.8021848
#
# Iteration [1900], Training MSE 0.9770693; Validation MSE 0.8724319
#
# Iteration [2000], Training MSE 1.0398588; Validation MSE 0.9748669
#
# Iteration [2100], Training MSE 0.9617594; Validation MSE 0.8236410
#
# Iteration [2200], Training MSE 0.9868658; Validation MSE 0.7598592
#
# Iteration [2300], Training MSE 1.5798092; Validation MSE 1.7573477
#
# Iteration [2400], Training MSE 0.9856435; Validation MSE 0.7804365
#
# Iteration [2500], Training MSE 0.9797776; Validation MSE 0.7511396
#
# Iteration [2600], Training MSE 1.1847341; Validation MSE 0.8128799
#
# Iteration [2700], Training MSE 0.9730268; Validation MSE 0.8068312
#
# Iteration [2800], Training MSE 1.2938058; Validation MSE 1.2884258
#
# Iteration [2900], Training MSE 1.6739477; Validation MSE 1.9402462
#
# Iteration [3000], Training MSE 0.9874871; Validation MSE 0.8483946
#
# Iteration [3100], Training MSE 3.7595758; Validation MSE 2.9377711
#
# Iteration [3200], Training MSE 0.9849161; Validation MSE 0.8026532
#
# Iteration [3300], Training MSE 1.7367135; Validation MSE 1.2037433
#
# Iteration [3400], Training MSE 0.9922959; Validation MSE 0.8441828
#
# Iteration [3500], Training MSE 9.3635082; Validation MSE 11.2566462
#
# Iteration [3600], Training MSE 0.9892568; Validation MSE 0.8015281
#
# Iteration [3700], Training MSE 1.4507800; Validation MSE 0.9760422
#
# Iteration [3800], Training MSE 0.9876174; Validation MSE 0.7801571
#
# Iteration [3900], Training MSE 8.7248087; Validation MSE 7.8510976
#
# Iteration [4000], Training MSE 0.8874704; Validation MSE 0.8314669
#
# Iteration [4100], Training MSE 0.7601676; Validation MSE 0.8003705
#
# Iteration [4200], Training MSE 0.7986045; Validation MSE 0.9104550
#
# Iteration [4300], Training MSE 0.6858986; Validation MSE 0.7879459
#
# Iteration [4400], Training MSE 0.6739351; Validation MSE 0.7654263
#
# Iteration [4500], Training MSE 0.6198901; Validation MSE 0.8931792
#
# Iteration [4600], Training MSE 0.6354533; Validation MSE 0.8912076
#
# Iteration [4700], Training MSE 0.7030461; Validation MSE 0.9731603
#
# Iteration [4800], Training MSE 0.6708813; Validation MSE 1.0127213
#
# Iteration [4900], Training MSE 0.6604540; Validation MSE 0.9092435
# Saving the trained model...
# Time taken for [5000] epochs:  0:03:54.139043
# Loss Summary:
# 	mae=0.5265517234802246
# 	mse=0.4521222710609436
# 	rmse=0.6724003553390503
# 	mape=5.021556854248047

# %%
# plt.close()
# plt.figure(figsize=(32, 16))
# plt.plot(predictions[1000]["train"].reshape(-1, 1), alpha=0.6)
# plt.plot(y_train.reshape(-1, 1), alpha=0.6)
# plt.legend(["Training Prediction", "Training Actual"])
# plt.grid(True)
# plt.title("Training Set Result")
# plt.show()

# %%
fig = plot_checkpoints(predictions, y_test, "test")

# %%
# plt.close()
# plt.figure(figsize=(32, 16))
# plt.plot(predictions[100]["test"].reshape(-1, 1), alpha=0.6)
# plt.plot(y_test.reshape(-1, 1), alpha=0.6)
# plt.legend(["Testing Prediction", "Testing Actual"])
# plt.grid(True)
# plt.title("Testing Set Result")
# plt.show()
