# %%
# %load_ext autotime

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint
# Out:
# time: 1.32 s

# %%
import sys
sys.path.extend(["../"])
from core.tools.data_import import *
from core.tools.time_series import *
from core.tools.visualize import *
from core.models.baseline_rnn import *
from constants import *
# Out:
# time: 3.88 ms

# %%
# Select a source of file.
pprint(UNRATE_DIR)
# file_dir_selected = input("Select Directory ")
file_dir_selected = "EC2"
# Out:
# {'EC2': '/home/ec2-user/code/AnnEconForecast/data/UNRATE.csv',
#  'MAC': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv'}
# time: 762 µs

# %%
# Pre-processing Parameters
PERIODS = 1
ORDER = 1
LAGS = 48
# Out:
# time: 921 µs

# %%
df = load_dataset(UNRATE_DIR[file_dir_selected])
prepared_df = differencing(df, periods=PERIODS, order=ORDER)
prepared_df.head()
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
#             UNRATE_period1_order1
# DATE
# 1948-01-01                    NaN
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# time: 20.8 ms

# %%
X_raw, y_raw = gen_supervised_sequence(
    prepared_df, LAGS, prepared_df.columns[0], sequential_label=True)
# Out:
# Total 800 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (800, 48, 1), y shape = (800, 48, 1)
# time: 57.1 ms

# %%
X_raw = X_raw.reshape(-1, LAGS,)
y_raw = y_raw.reshape(-1, LAGS,)
print(X_raw.shape, y_raw.shape)
# Out:
# (800, 48) (800, 48)
# time: 600 µs

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X_raw, y_raw,
    test_size=0.2,
    shuffle=False
)

(X_train, X_val,
 y_train, y_val) = train_test_split(
    X_train, y_train,
    test_size=0.2,
    shuffle=False
)
# Out:
# time: 1.84 ms

# %%
# Expand dimension so it fits the RNN input place holder.
# (Num_Sample, time_steps, 1)
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
X_val = np.expand_dims(X_val, axis=-1)
# Out:
# time: 750 µs

# %%
y_train = np.expand_dims(y_train, axis=-1)
y_test = np.expand_dims(y_test, axis=-1)
y_val = np.expand_dims(y_val, axis=-1)
# Out:
# time: 1.12 ms

# %%
print(f"Training and testing set generated,\
\nX_train shape: {X_train.shape}\
\ny_train shape: {y_train.shape}\
\nX_test shape: {X_test.shape}\
\ny_test shape: {y_test.shape}\
\nX_validation shape: {X_val.shape}\
\ny_validation shape: {y_val.shape}")
# Out:
# Training and testing set generated,
# X_train shape: (512, 48, 1)
# y_train shape: (512, 48, 1)
# X_test shape: (160, 48, 1)
# y_test shape: (160, 48, 1)
# X_validation shape: (128, 48, 1)
# y_validation shape: (128, 48, 1)
# time: 1.33 ms

# %%
# One Sample
plt.figure(figsize=(15, 5))
plt.title("The last training sample")
plt.plot(X_train[-1])
plt.plot(y_train[-1], "-o")
plt.legend(["X", "y"])
plt.grid(True)
plt.show()
# Out:
# time: 208 ms

# %%
# Model Parameters
num_time_steps = LAGS
# Number of series used to predict. (including concurrent)
num_inputs = 1
num_outputs = 1
num_neurons = 256
# Number of output series
learning_rate = 0.03
epochs = 1000
# Training Settings
report_periods = 100
# Out:
# time: 587 µs

# %%
parameters = {
    "num_time_steps": LAGS,
    "num_inputs": 1,
    "num_outputs": 1,
    "num_neurons": 64,
    "learning_rate": 0.1
}
# Out:
# time: 1.07 ms

# %%
model = BaselineRnn(para=parameters, sequential_label=True)
# Out:
# Model: loading parameters
# Building placeholders...
# Building core rnn...
# Building metrics and operations...
# time: 3.88 s

# %%
hist = {"train": [], "val": []}
with tf.Session() as sess:
    sess.run(model.init)
    for e in range(epochs):
        progbar(e, epochs-1, epochs//10)
        sess.run(model.train,
                 feed_dict={model.X: X_train, model.y: y_train})
        if e % report_periods == 0:
            eval_loss = lambda A, B: model.loss.eval(
                feed_dict={model.X: A, model.y: B})
#             train_mse = loss.eval(feed_dict={X: X_train, y: y_train})
#             val_mse = loss.eval(feed_dict={X: X_val, y: y_val})
            train_mse = eval_loss(X_train, y_train)
            val_mse = eval_loss(X_val, y_val)
            hist["train"].append(train_mse)
            hist["val"].append(val_mse)
            print(f"\nIteration [{e}], Training MSE {train_mse:0.7f}; Validation MSE {val_mse:0.7f}")
    
    gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})[:,-1]
    p_train = gen_pred(X_train)
    p_test = gen_pred(X_test)
# Out:
#  ---------------------------------------------------------------------------------------------------- [  0.00%]
# Iteration [0], Training MSE 1.9788355; Validation MSE 1.1865939
#  ##########------------------------------------------------------------------------------------------ [ 10.01%]
# Iteration [100], Training MSE 0.0464150; Validation MSE 0.0201046
#  ####################-------------------------------------------------------------------------------- [ 20.02%]
# Iteration [200], Training MSE 0.0435920; Validation MSE 0.0186233
#  ##############################---------------------------------------------------------------------- [ 30.03%]
# Iteration [300], Training MSE 0.0427760; Validation MSE 0.0181077
#  ########################################------------------------------------------------------------ [ 40.04%]
# Iteration [400], Training MSE 0.0419530; Validation MSE 0.0176738
#  ##################################################-------------------------------------------------- [ 50.05%]
# Iteration [500], Training MSE 0.0393335; Validation MSE 0.0173192
#  ############################################################---------------------------------------- [ 60.06%]
# Iteration [600], Training MSE 0.0362339; Validation MSE 0.0173797
#  ######################################################################------------------------------ [ 70.07%]
# Iteration [700], Training MSE 0.0335833; Validation MSE 0.0182571
#  ################################################################################-------------------- [ 80.08%]
# Iteration [800], Training MSE 0.0302699; Validation MSE 0.0266510
#  ##########################################################################################---------- [ 90.09%]
# Iteration [900], Training MSE 0.0303694; Validation MSE 0.0219897
#  #################################################################################################### [100.00%]time: 1min 13s

# %%
model.y
# Out:
# <tf.Tensor 'Output_placeholder:0' shape=(?, 48, 1) dtype=float32>
# time: 1.44 ms

# %%
# Visualize testing set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Testing Set Result")
plt.plot(np.squeeze(p_test[:,-1]))
plt.plot(np.squeeze(y_test[:,-1]))
plt.legend(["Test Prediction", "Test Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 624 ms

# %%
# Visualize training set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Training Set Result")
plt.plot(np.squeeze(p_train), alpha=0.8)
plt.plot(np.squeeze(y_train[:,-1]), alpha=0.8)
plt.legend(["Training Prediction", "Training Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 692 ms

# %%
plt.close()
plt.plot(np.log(hist["train"]))
plt.plot(np.log(hist["val"]))
plt.legend(["Log Training Loss", "Log Validation Loss"])
plt.show()
# Out:
# time: 112 ms
