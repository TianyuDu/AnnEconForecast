# %%
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1 ms

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint
# Out:
# time: 1.4 ms

# %%
import sys
sys.path.extend(["../"])
from core.tools.data_import import *
from core.tools.time_series import *
from core.tools.visualize import *
from core.models.baseline_rnn import *
from constants import *
# Out:
# time: 1.37 ms

# %%
# Select a source of file.
pprint(UNRATE_DIR)
# file_dir_selected = input("Select Directory ")
file_dir_selected = "EC2GPU"
# Out:
# {'EC2': '/home/ec2-user/code/AnnEconForecast/data/UNRATE.csv',
#  'EC2GPU': '/home/ubuntu/AnnEconForecast/data/UNRATE.csv',
#  'MAC': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv'}
# time: 1.17 ms

# %%
# Pre-processing Parameters
PERIODS = 1
ORDER = 1
LAGS = 48
# Out:
# time: 834 µs

# %%
df = load_dataset(UNRATE_DIR[file_dir_selected])
prepared_df = differencing(df, periods=PERIODS, order=ORDER)
prepared_df.head()
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
#             UNRATE_period1_order1
# DATE
# 1948-01-01                    NaN
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4
# time: 19 ms

# %%
X_raw, y_raw = gen_supervised_sequence(
    prepared_df, LAGS, prepared_df.columns[0], sequential_label=True)
# Out:
# Total 800 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (800, 48, 1), y shape = (800, 48, 1)
# time: 89.7 ms

# %%
# X_raw = X_raw.reshape(-1, LAGS,)
# y_raw = y_raw.reshape(-1, LAGS,)
# print(X_raw.shape, y_raw.shape)
# Out:
# time: 599 µs

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X_raw, y_raw,
    test_size=0.2,
    shuffle=False
)

(X_train, X_val,
 y_train, y_val) = train_test_split(
    X_train, y_train,
    test_size=0.2,
    shuffle=False
)
# Out:
# time: 2.89 ms

# %%
# # Expand dimension so it fits the RNN input place holder.
# # (Num_Sample, time_steps, 1)
# X_train = np.expand_dims(X_train, axis=-1)
# X_test = np.expand_dims(X_test, axis=-1)
# X_val = np.expand_dims(X_val, axis=-1)
# Out:
# time: 646 µs

# %%
# y_train = np.expand_dims(y_train, axis=-1)
# y_test = np.expand_dims(y_test, axis=-1)
# y_val = np.expand_dims(y_val, axis=-1)
# Out:
# time: 581 µs

# %%
print(f"Training and testing set generated,\
\nX_train shape: {X_train.shape}\
\ny_train shape: {y_train.shape}\
\nX_test shape: {X_test.shape}\
\ny_test shape: {y_test.shape}\
\nX_validation shape: {X_val.shape}\
\ny_validation shape: {y_val.shape}")
# Out:
# Training and testing set generated,
# X_train shape: (512, 48, 1)
# y_train shape: (512, 48, 1)
# X_test shape: (160, 48, 1)
# y_test shape: (160, 48, 1)
# X_validation shape: (128, 48, 1)
# y_validation shape: (128, 48, 1)
# time: 1.44 ms

# %%
# One Sample
plt.figure(figsize=(15, 5))
plt.title("The last training sample")
plt.plot(X_train[0])
plt.plot(y_train[0], "-o")
plt.legend(["X", "y"])
plt.grid(True)
plt.show()
# Out:
# time: 203 ms

# %%
# Model Parameters
num_time_steps = LAGS
# Number of series used to predict. (including concurrent)
num_inputs = 1
num_outputs = 1
num_neurons = 64
# Number of output series
learning_rate = 0.03
epochs = 900
# Training Settings
report_periods = epochs // 20
# Out:
# time: 1.24 ms

# %%
parameters = {
    "num_time_steps": LAGS,
    "num_inputs": 1,
    "num_outputs": 1,
    "num_neurons": 2048,
    "learning_rate": 0.3
}
# Out:
# time: 1.22 ms

# %%
model = BaselineRnn(para=parameters, sequential_label=True)
# Out:
# Model: loading parameters
# Building placeholders...
# Building core rnn...
# Building metrics and operations...
# time: 597 ms

# %%
# Inspect Models.
model.learning_rate
# Out:
# 0.3
# time: 2.04 ms

# %%
hist = {"train": [], "val": []}
with tf.Session() as sess:
    sess.run(model.init)
    for e in range(epochs):
        progbar(e, epochs-1, 0)
        sess.run(model.train,
                 feed_dict={model.X: X_train, model.y: y_train})
        if e % report_periods == 0:
            eval_loss = lambda pred, resp: model.loss.eval(
                feed_dict={model.X: pred, model.y: resp})
            train_mse = eval_loss(X_train, y_train)
            val_mse = eval_loss(X_val, y_val)
            hist["train"].append(train_mse)
            hist["val"].append(val_mse)
            print(f"Iteration [{e}], Training MSE {train_mse:0.7f}; Validation MSE {val_mse:0.7f}")
    
    if model.SL:
        gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})[:,-1]
    else:
        gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})
    p_train = gen_pred(X_train)
    p_test = gen_pred(X_test)
# Out:
#   [  0.00%]Iteration [0], Training MSE 43964.1992188; Validation MSE 43943.8007812
#   [  5.01%]Iteration [45], Training MSE 82.5146713; Validation MSE 53.6306572
#   [ 10.01%]Iteration [90], Training MSE 19.8024464; Validation MSE 6.7366643
#   [ 15.02%]Iteration [135], Training MSE 13.5252953; Validation MSE 4.2863789
#   [ 20.02%]Iteration [180], Training MSE 9.6252718; Validation MSE 2.8895199
#   [ 25.03%]Iteration [225], Training MSE 6.7026362; Validation MSE 1.9269075
#   [ 30.03%]Iteration [270], Training MSE 4.5757427; Validation MSE 1.2596660
#   [ 35.04%]Iteration [315], Training MSE 3.1036265; Validation MSE 0.8097026
#   [ 40.04%]Iteration [360], Training MSE 2.1246893; Validation MSE 0.5177659
#   [ 45.05%]Iteration [405], Training MSE 1.4849831; Validation MSE 0.3355666
#   [ 50.06%]Iteration [450], Training MSE 1.0904986; Validation MSE 0.2243539
#   [ 55.06%]Iteration [495], Training MSE 0.8477774; Validation MSE 0.1593484
#   [ 60.07%]Iteration [540], Training MSE 105.4348984; Validation MSE 105.0526733
#   [ 65.07%]Iteration [585], Training MSE 0.8262413; Validation MSE 0.3248517
#   [ 70.08%]Iteration [630], Training MSE 0.5914583; Validation MSE 0.1368072
#   [ 75.08%]Iteration [675], Training MSE 0.5220463; Validation MSE 0.1003274
#   [ 80.09%]Iteration [720], Training MSE 0.4792400; Validation MSE 0.0903098
#   [ 85.09%]Iteration [765], Training MSE 0.4443183; Validation MSE 0.0819956
#   [ 90.10%]Iteration [810], Training MSE 0.4146338; Validation MSE 0.0749599
#   [ 95.11%]Iteration [855], Training MSE 60.2154198; Validation MSE 59.8693733
#   [100.00%]time: 3min 40s

# %%
# Visualize testing set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Testing Set Result")
if model.SL:
    plt.plot(np.squeeze(p_test[:,-1]))
    plt.plot(np.squeeze(y_test[:,-1]))
else:
    plt.plot(np.squeeze(p_test))
    plt.plot(np.squeeze(y_test))
plt.legend(["Test Prediction", "Test Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 779 ms

# %%
# Visualize training set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Training Set Result")
if model.SL:
    plt.plot(np.squeeze(p_train[:,-1]), alpha=0.8)
    plt.plot(np.squeeze(y_train[:,-1]), alpha=0.8)
else:
    plt.plot(np.squeeze(p_train), alpha=0.8)
    plt.plot(np.squeeze(y_train), alpha=0.8)
plt.legend(["Training Prediction", "Training Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 884 ms

# %%
plt.close()
plt.plot(np.log(hist["train"]))
plt.plot(np.log(hist["val"]))
plt.legend(["Log Training Loss", "Log Validation Loss"])
plt.show()
# Out:
# time: 187 ms
