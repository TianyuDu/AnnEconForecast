# %%
# Created: Dec. 17. 2018
# Use this notebook to restore saved tensorflow models.

# %%
import os
import sys
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
sys.path.append("../")

# %%
import hps_configs.mac_config as config
import core.tools.rnn_prepare as rnn_prepare
import constants

# %%
param = config.main

# %%
param["LAGS"] = 6
param["num_neurons"] = (256, 512)
param["learning_rate"] = 0.03

# %%
DIR = "/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/docs/demo source/demo2/meta"
META = "LAGS=6-epochs=800-num_neurons=(256, 512)-learning_rate=0.03.meta"
FILE_DIR = constants.DATA_DIR["a"]

# %%
tf.reset_default_graph()

# %%
prepared_df = rnn_prepare.prepare_dataset(
    file_dir=FILE_DIR,
    periods=param["PERIODS"],
    order=param["ORDER"],
    remove=None,
    verbose=False
)
(X_train, X_val, X_test,
 y_train, y_val, y_test) = rnn_prepare.split_dataset(
    raw=prepared_df,
    train_ratio=param["TRAIN_RATIO"],
    val_ratio=param["VAL_RATIO"],
    lags=param["LAGS"]
)
data_collection = {
    "X_train": X_train,
    "X_val": X_val,
    "X_test": X_test,
    "y_train": y_train,
    "y_val": y_val,
    "y_test": y_test
}
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# StandardScaler applied, scaling based on the first 679 observations.
# Total 842 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (842, 6, 1), y shape = (842, 1, 1)
# Training and testing set generated,
# X_train shape: (672, 6, 1)
# y_train shape: (672, 1)
# X_test shape: (85, 6, 1)
# y_test shape: (85, 1)
# X_validation shape: (85, 6, 1)
# y_validation shape: (85, 1)

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    saver = tf.train.import_meta_graph(DIR + "/" + META)
    saver.restore(sess, DIR)
#     print(sess.run("DATA_FEED/Feature_X"))
    graph = tf.get_default_graph()
    X = graph.get_tensor_by_name("DATA_FEED/FEATURE:0")
    pred = graph.get_tensor_by_name("OUTPUT_LAYER/PREDICTION:0")
#     print(sess.run("OUTPUT_LAYER/Prediction"))

    def make_pred(feed_X):
        return pred.eval(feed_dict={X: feed_X})
    
    p_train = make_pred(X_train)
    p_val = make_pred(X_val)
    p_test = make_pred(X_test)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-33-e1f264606bce> in <module>()
#       2     init = tf.global_variables_initializer()
#       3     sess.run(init)
# ----> 4     saver = tf.train.import_meta_graph(DIR + "/" + META)
#       5     saver.restore(sess, DIR)
#       6 #     print(sess.run("DATA_FEED/Feature_X"))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1672   """  # pylint: disable=g-doc-exception
#    1673   return _import_meta_graph_with_return_elements(
# -> 1674       meta_graph_or_file, clear_devices, import_scope, **kwargs)[0]
#    1675
#    1676
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/saver.py in _import_meta_graph_with_return_elements(meta_graph_or_file, clear_devices, import_scope, return_elements, **kwargs)
#    1684                        "execution is enabled.")
#    1685   if not isinstance(meta_graph_or_file, meta_graph_pb2.MetaGraphDef):
# -> 1686     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#    1687   else:
#    1688     meta_graph_def = meta_graph_or_file
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/meta_graph.py in read_meta_graph_file(filename)
#     631   meta_graph_def = meta_graph_pb2.MetaGraphDef()
#     632   if not file_io.file_exists(filename):
# --> 633     raise IOError("File %s does not exist." % filename)
#     634   # First try to read it as a binary file.
#     635   file_content = file_io.FileIO(filename, "rb").read()
#
# OSError: File /Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/docs/demo source/demo2/meta/main.meta does not exist.

# %%
    # sess = tf.Session()
# sess.run(tf.global_variables_initializer())
# imported_meta = tf.train.import_meta_graph(DIR + META)
# imported_meta.restore(sess, tf.train.latest_checkpoint(DIR))

# %%
trainable_var = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)

# %%
tf.get_collection("Prediction")
# Out:
# []

# %%
plt.close()
plt.figure(figsize=(32,8))
plt.plot(p_test)
plt.plot(y_test)
plt.grid(True)

# %%
plt.close()
plt.plot(p_train)
plt.plot(y_train, alpha=0.6)
