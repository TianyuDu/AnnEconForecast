# %%
# %load_ext autotime
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
import matplotlib
import matplotlib.pyplot as plt

# %%
import sys
sys.path.extend(["../"])
# Out:
# time: 697 µs

# %%
from sklearn.model_selection import train_test_split
from core.tools.data_import import *
from core.tools.time_series import *
from constants import *
# Out:
# time: 136 ms

# %%
from pprint import pprint
pprint(UNRATE_DIR)
file_dir = input("Select Directory ")
# Out:
# {'EC2': '/home/ec2-user/code/AnnEconForecast/data/UNRATE.csv',
#  'MAC': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv'}
# Select Directory EC2
# time: 1.77 s

# %%
df = load_dataset(UNRATE_DIR["EC2"])
df_d1 = differencing(df, periods=1, order=1)

lags = list(range(1, 12))
X_FEATURES = len(lags)
X_raw, y_raw = gen_supervised(df_d1, predictors=lags)
X_raw, y_raw = clean_nan(X_raw, y_raw)
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# 12 (1.41%) observations with Nan are dropped.
# time: 21.1 ms

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X_raw, y_raw,
    test_size=0.2,
    shuffle=False
)

(X_train, X_val,
 y_train, y_val) = train_test_split(
    X_train, y_train,
    test_size=0.2,
    shuffle=False
)
# Out:
# time: 3.42 ms

# %%
# Expand dimension so it fits the RNN input place holder.
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
X_val = np.expand_dims(X_val, axis=2)

y_train = np.expand_dims(y_train, axis=1)
y_test = np.expand_dims(y_test, axis=1)
y_val = np.expand_dims(y_val, axis=1)
# Out:
# time: 1.13 ms

# %%
print(f"Training and testing set generated,\
\nX_train shape: {X_train.shape}\
\ny_train shape: {y_train.shape}\
\nX_test shape: {X_test.shape}\
\ny_test shape: {y_test.shape}\
\nX_validation shape: {X_val.shape}\
\ny_validation shape: {y_val.shape}")
# Out:
# Training and testing set generated,
# X_train shape: (536, 11, 1)
# y_train shape: (536, 1, 1)
# X_test shape: (168, 11, 1)
# y_test shape: (168, 1, 1)
# X_validation shape: (134, 11, 1)
# y_validation shape: (134, 1, 1)
# time: 700 µs

# %%
num_time_steps = len(lags)
# Number of series used to predict. (including concurrent)
num_inputs = 1
num_neurons = 256
# Number of output series
num_outputs = 1
learning_rate = 0.01
num_iter = 100
batch_size = 1
# Out:
# time: 645 µs

# %%
# THIS IS REAL
size_train = 24*28 + 1
train = df_d1[:size_train]
test = df_d1[size_train:]
print(train.shape)
print(test.shape)
# Out:
# (673, 1)
# (177, 1)
# time: 1.34 ms

# %%
X_data = train[:size_train-1]
X_batches = X_data.values.reshape(-1, num_time_steps, 1)
print(x_batches.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-c9d167dc93a5> in <module>
#       1 X_data = train[:size_train-1]
# ----> 2 X_batches = X_data.values.reshape(-1, num_time_steps, 1)
#       3 print(x_batches.shape)
#
# ValueError: cannot reshape array of size 672 into shape (11,1)
# time: 13.4 ms

# %%
y_data = train[num_outputs: size_train]
y_batches = y_data.values.reshape(-1, num_time_steps, num_outputs)
print(y_batches.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-a16a0d567ec9> in <module>
#       1 y_data = train[num_outputs: size_train]
# ----> 2 y_batches = y_data.values.reshape(-1, num_time_steps, num_outputs)
#       3 print(y_batches.shape)
#
# ValueError: cannot reshape array of size 672 into shape (11,1)
# time: 12.9 ms

# %%
tf.reset_default_graph()
# setting up
X = tf.placeholder(
    tf.float32,
    [None, num_time_steps, num_inputs],
    name="Input_placeholder")
# y = tf.placeholder(
#     tf.float32,
#     [None, num_time_steps, num_outputs],
#     name="Output_placeholder")
y = tf.placeholder(tf.float32)
# Out:
# time: 2.95 ms

# %%
# Build RNN.
cell = tf.contrib.rnn.GRUCell(
    num_units=num_neurons
)
    
rnn_output, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)
stacked_rnn_output = tf.reshape(rnn_output, [-1, num_neurons])

stacked_outputs = tf.layers.dense(stacked_rnn_output, num_outputs)
outputs = tf.reshape(stacked_outputs, [-1, num_time_steps, num_outputs])

last_output = outputs[:, -1, :]
# Out:
# time: 107 ms

# %%
outputs
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 11, 1) dtype=float32>
# time: 1.95 ms

# %%
# Operators
loss = tf.reduce_mean(tf.square(last_output - y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.03)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()
# Out:
# time: 378 ms

# %%
X_train.shape
num_iter = 300
# Out:
# time: 628 µs

# %%
hist = {"train": [], "val": []}
with tf.Session() as sess:
    sess.run(init)
    for e in range(num_iter):
        sess.run(train,
                 feed_dict={X: X_test, y: y_train})
        if e % 10 == 0:
            train_mse = loss.eval(feed_dict={X: X_train, y: y_train})
            print(f"Iteratin [{e}]: Training MSE {train_mse}")
#             val_mse = loss.eval(feed_dict={X: X_val, y: y_val})
#             hist["train"].append(train_mse)
#             hist["val"].append(val_mse)
#             print(f"Iteration [{e}], Training MSE {train_mse:0.7f}; Validation MSE {val_mse:0.7f}")
    
    gen_pred = lambda src: np.squeeze(last_output.eval(feed_dict={X: src}))
    p_train = gen_pred(X_train)
    p_test = gen_pred(X_test)
# Out:
# Iteratin [0]: Training MSE 0.05452775955200195
# Iteratin [10]: Training MSE 0.05451183393597603
# Iteratin [20]: Training MSE 0.054511070251464844
# Iteratin [30]: Training MSE 0.0545109324157238
# Iteratin [40]: Training MSE 0.05451085790991783
# Iteratin [50]: Training MSE 0.05451072007417679
# Iteratin [60]: Training MSE 0.05451067537069321
# Iteratin [70]: Training MSE 0.05451048165559769
# Iteratin [80]: Training MSE 0.05451023578643799
# Iteratin [90]: Training MSE 0.054510097950696945
# Iteratin [100]: Training MSE 0.05450979620218277
# Iteratin [110]: Training MSE 0.05450977385044098
# Iteratin [120]: Training MSE 0.05450945347547531
# Iteratin [130]: Training MSE 0.05450943112373352
# Iteratin [140]: Training MSE 0.05450967699289322
# Iteratin [150]: Training MSE 0.05450921505689621
# Iteratin [160]: Training MSE 0.05450901761651039
# Iteratin [170]: Training MSE 0.054508768022060394
# Iteratin [180]: Training MSE 0.05450841784477234
# Iteratin [190]: Training MSE 0.054508697241544724
# Iteratin [200]: Training MSE 0.05450860783457756
# Iteratin [210]: Training MSE 0.05450848117470741
#        -5.49605209e-03, -4.67922026e-03,  2.08880799e-03,  5.15567651e-03,
#        -6.05742796e-04,  3.00365151e-04,  2.78271385e-04,  1.41534826e-03,
#         3.28886462e-03,  9.63800959e-03,  6.24390901e-04,  8.87566060e-03,
#         1.05881048e-02,  8.82300269e-03,  8.64505488e-03,  9.12071485e-03,
#         7.48232333e-03,  5.81003586e-03,  8.09088908e-03,  9.75165330e-03,
#         6.17561536e-03,  4.28430620e-04,  6.56341994e-03,  8.39900877e-03,
#         4.25869739e-03,  7.25022191e-03,  3.45210359e-03,  5.00474544e-03,
#         5.69316279e-03,  2.73875706e-03,  3.47007485e-03,  5.34017710e-03,
#         2.41722027e-03,  7.36316945e-03,  1.04057817e-02,  5.56380814e-03,
#         5.82136912e-03,  7.22329551e-03,  5.95610589e-03,  6.04685629e-03,
#        -4.11496311e-03,  3.78037011e-03,  4.44528274e-03,  2.51904503e-03,
#         4.17749863e-03,  6.35579554e-03,  3.69781302e-03,  1.47608633e-03,
#         3.86379845e-03,  5.96554019e-03,  7.72646768e-03,  2.92551657e-03,
#         3.38583905e-03,  5.01872553e-03,  8.24921578e-03,  4.63288510e-03,
#         5.43940393e-03,  6.22643158e-03,  5.53924730e-03,  5.07220114e-03,
#         4.49721515e-03,  7.80344615e-03,  5.86197386e-03,  4.30932036e-03,
#         4.89406474e-03,  6.40022429e-03,  8.02878849e-03,  1.78652885e-03,
#         7.04669533e-03,  3.56432190e-03,  3.09477700e-03,  7.95396045e-03,
#         5.45620266e-03,  6.79159118e-03,  5.43282647e-03,  6.07296359e-03,
#         9.97722894e-03,  7.81609956e-03,  2.39878707e-03,  4.80273040e-03,
#         4.83088335e-03,  7.00310199e-03,  4.22406010e-03,  3.98943154e-03,
#         5.75952977e-03,  5.66559471e-03,  7.56490277e-03,  9.17320140e-03,
#         1.06102172e-02,  9.51235183e-03,  6.80486159e-03,  1.05063478e-02,
#         9.86591540e-03,  2.88439589e-03,  4.18499066e-03,  4.05650958e-03,
#         5.42417122e-03,  1.44638179e-03,  4.17799968e-03,  3.27230105e-03,
#         2.89665349e-03,  4.14081616e-03,  7.59673258e-03,  4.33043111e-03,
#         7.60605326e-03,  8.56893230e-03,  6.37375703e-03,  6.75455527e-03,
#         4.68852650e-03,  4.58106073e-03,  4.17434261e-04,  4.60881740e-03,
#         3.28770420e-03,  3.77213722e-03,  1.76619843e-03, -1.08771108e-03,
#         1.20086945e-03,  5.94325410e-03,  5.70473401e-03,  5.18553378e-03],
#       dtype=float32)
# time: 6.61 ms

# %%
plt.close()
plt.figure(figsize=(32,16))
plt.plot(p_test)
plt.plot(np.squeeze(y_test))
plt.legend(["Test Prediction", "Test Actual"])
plt.show()
# Out:
# time: 588 ms

# %%
plt.close()
plt.figure(figsize=(32,16))
plt.plot(pred_val)
plt.plot(np.squeeze(y_val))
plt.legend(["Validation Prediction", "Validation Actual"])
plt.show()
# Out:
# time: 587 ms

# %%
plt.close()
plt.plot(np.log(hist["train"]))
plt.plot(np.log(hist["val"]))
plt.legend(["Log Training Loss", "Log Validation Loss"])
plt.show()
