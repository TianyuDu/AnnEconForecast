# %%
# %load_ext autotime
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
import matplotlib
import matplotlib.pyplot as plt

# %%
import sys
sys.path.extend(["../"])
# Out:
# time: 988 µs

# %%
from sklearn.model_selection import train_test_split
from core.tools.data_import import *
from core.tools.time_series import *
from constants import *
# Out:
# time: 394 ms

# %%
from pprint import pprint
pprint(UNRATE_DIR)
file_dir_selected = input("Select Directory ")
# Out:
# {'EC2': '/home/ec2-user/code/AnnEconForecast/data/UNRATE.csv',
#  'MAC': '/Users/tianyudu/Documents/Academics/EconForecasting/AnnEconForecast/data/UNRATE.csv'}
# Select Directory MAC
# time: 2.17 s

# %%
df = load_dataset(UNRATE_DIR[file_dir_selected])
df_d1 = differencing(df, periods=1, order=1)
LAGS = 48
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
# time: 25.8 ms

# %%
X_raw, y_raw = gen_supervised_rnn(df_d1, LAGS)
# Out:
# time: 94.1 ms

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X_raw, y_raw,
    test_size=0.2,
    shuffle=False
)

(X_train, X_val,
 y_train, y_val) = train_test_split(
    X_train, y_train,
    test_size=0.2,
    shuffle=False
)
# Out:
# time: 3.82 ms

# %%
# Expand dimension so it fits the RNN input place holder.
# (Num_Sample, )
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
X_val = np.expand_dims(X_val, axis=2)

y_train = np.expand_dims(y_train, axis=2)
y_test = np.expand_dims(y_test, axis=2)
y_val = np.expand_dims(y_val, axis=2)
# Out:
# time: 1.9 ms

# %%
print(f"Training and testing set generated,\
\nX_train shape: {X_train.shape}\
\ny_train shape: {y_train.shape}\
\nX_test shape: {X_test.shape}\
\ny_test shape: {y_test.shape}\
\nX_validation shape: {X_val.shape}\
\ny_validation shape: {y_val.shape}")
# Out:
# Training and testing set generated,
# X_train shape: (512, 48, 1)
# y_train shape: (512, 48, 1)
# X_test shape: (160, 48, 1)
# y_test shape: (160, 48, 1)
# X_validation shape: (128, 48, 1)
# y_validation shape: (128, 48, 1)
# time: 1.63 ms

# %%
num_time_steps = LAGS
# Number of series used to predict. (including concurrent)
num_inputs = 1
num_neurons = 64
# Number of output series
num_outputs = 1
learning_rate = 0.3
epochs = 1000
batch_size = 1
# Out:
# time: 1.65 ms

# %%
# THIS IS REAL
size_train = 24*28 + 1
train = df_d1[:size_train]
test = df_d1[size_train:]
print(train.shape)
print(test.shape)
# Out:
# (673, 1)
# (177, 1)
# time: 2.08 ms

# %%
tf.reset_default_graph()
# setting up
X = tf.placeholder(
    tf.float32,
    [None, num_time_steps, num_inputs],
    name="Input_placeholder")
y = tf.placeholder(
    tf.float32,
    [None, num_time_steps, num_outputs],
    name="Output_placeholder")
# Out:
# time: 4.64 ms

# %%
# Build RNN.
cell = tf.contrib.rnn.LSTMCell(
    num_units=num_neurons
)
    
rnn_output, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)
stacked_rnn_output = tf.reshape(rnn_output, [-1, num_neurons])

stacked_outputs = tf.layers.dense(stacked_rnn_output, num_outputs)
outputs = tf.reshape(stacked_outputs, [-1, num_time_steps, num_outputs])

# last_output = outputs[:, -1, :]
# Out:
# time: 127 ms

# %%
num_neurons
# Out:
# 64
# time: 2.12 ms

# %%
# Operators
loss = tf.reduce_mean(tf.square(outputs - y))
optimizer = tf.train.AdadeltaOptimizer(learning_rate=learning_rate)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()
# Out:
# time: 370 ms

# %%
y
# Out:
# <tf.Tensor 'Output_placeholder:0' shape=(?, 48, 1) dtype=float32>
# time: 2.92 ms

# %%
hist = {"train": [], "val": []}
with tf.Session() as sess:
    sess.run(init)
    for e in range(epochs):
        sess.run(train,
                 feed_dict={X: X_train, y: y_train})
        if e % 10 == 0:
            train_mse = loss.eval(feed_dict={X: X_train, y: y_train})
#             print(f"Iteratin [{e}]: Training MSE {train_mse}")
            val_mse = loss.eval(feed_dict={X: X_val, y: y_val})
            hist["train"].append(train_mse)
            hist["val"].append(val_mse)
            print(f"Iteration [{e}], Training MSE {train_mse:0.7f}; Validation MSE {val_mse:0.7f}")
    
    gen_pred = lambda src: outputs.eval(feed_dict={X: src})[:,-1]
    p_train = gen_pred(X_train)
    p_test = gen_pred(X_test)
# Out:
# Iteration [0], Training MSE 0.0485293; Validation MSE 0.0186983
# Iteration [10], Training MSE 0.0481677; Validation MSE 0.0186908
# Iteration [20], Training MSE 0.0478424; Validation MSE 0.0186280
# Iteration [30], Training MSE 0.0475470; Validation MSE 0.0185741
# Iteration [40], Training MSE 0.0472789; Validation MSE 0.0185285
# Iteration [50], Training MSE 0.0470353; Validation MSE 0.0184902
# Iteration [60], Training MSE 0.0468137; Validation MSE 0.0184586
# Iteration [70], Training MSE 0.0466115; Validation MSE 0.0184329
# Iteration [80], Training MSE 0.0464264; Validation MSE 0.0184125
# Iteration [90], Training MSE 0.0462564; Validation MSE 0.0183969
# Iteration [100], Training MSE 0.0460995; Validation MSE 0.0183856
# Iteration [110], Training MSE 0.0459543; Validation MSE 0.0183781
# Iteration [120], Training MSE 0.0458193; Validation MSE 0.0183740
# Iteration [130], Training MSE 0.0456932; Validation MSE 0.0183729
# Iteration [140], Training MSE 0.0455749; Validation MSE 0.0183745
# Iteration [150], Training MSE 0.0454637; Validation MSE 0.0183786
# Iteration [160], Training MSE 0.0453586; Validation MSE 0.0183848
# Iteration [170], Training MSE 0.0452590; Validation MSE 0.0183930
# Iteration [180], Training MSE 0.0451644; Validation MSE 0.0184029
# Iteration [190], Training MSE 0.0450742; Validation MSE 0.0184144
# Iteration [200], Training MSE 0.0449883; Validation MSE 0.0184272
# Iteration [210], Training MSE 0.0449061; Validation MSE 0.0184414
# Iteration [220], Training MSE 0.0448277; Validation MSE 0.0184568
# Iteration [230], Training MSE 0.0447526; Validation MSE 0.0184732
# Iteration [240], Training MSE 0.0446809; Validation MSE 0.0184905
# Iteration [250], Training MSE 0.0446124; Validation MSE 0.0185088
# Iteration [260], Training MSE 0.0445472; Validation MSE 0.0185278
# Iteration [270], Training MSE 0.0444850; Validation MSE 0.0185476
# Iteration [280], Training MSE 0.0444260; Validation MSE 0.0185679
# Iteration [290], Training MSE 0.0443700; Validation MSE 0.0185888
# Iteration [300], Training MSE 0.0443172; Validation MSE 0.0186099
# Iteration [310], Training MSE 0.0442675; Validation MSE 0.0186309
# Iteration [320], Training MSE 0.0442210; Validation MSE 0.0186503
# Iteration [330], Training MSE 0.0441776; Validation MSE 0.0186697
# Iteration [340], Training MSE 0.0441373; Validation MSE 0.0186903
# Iteration [350], Training MSE 0.0441000; Validation MSE 0.0187111
# Iteration [360], Training MSE 0.0440658; Validation MSE 0.0187317
# Iteration [370], Training MSE 0.0440344; Validation MSE 0.0187519
# Iteration [380], Training MSE 0.0440058; Validation MSE 0.0187717
# Iteration [390], Training MSE 0.0439799; Validation MSE 0.0187909
# Iteration [400], Training MSE 0.0439565; Validation MSE 0.0188095
# Iteration [410], Training MSE 0.0439356; Validation MSE 0.0188273
# Iteration [420], Training MSE 0.0439167; Validation MSE 0.0188443
# Iteration [430], Training MSE 0.0438999; Validation MSE 0.0188605
# Iteration [440], Training MSE 0.0438849; Validation MSE 0.0188757
# Iteration [450], Training MSE 0.0438716; Validation MSE 0.0188899
# Iteration [460], Training MSE 0.0438597; Validation MSE 0.0189031
# Iteration [470], Training MSE 0.0438492; Validation MSE 0.0189154
# Iteration [480], Training MSE 0.0438397; Validation MSE 0.0189266
# Iteration [490], Training MSE 0.0438312; Validation MSE 0.0189368
# Iteration [500], Training MSE 0.0438236; Validation MSE 0.0189460
# Iteration [510], Training MSE 0.0438165; Validation MSE 0.0189543
# Iteration [520], Training MSE 0.0438101; Validation MSE 0.0189617
# Iteration [530], Training MSE 0.0438042; Validation MSE 0.0189683
# Iteration [540], Training MSE 0.0437986; Validation MSE 0.0189740
# Iteration [550], Training MSE 0.0437934; Validation MSE 0.0189790
# Iteration [560], Training MSE 0.0437884; Validation MSE 0.0189833
# Iteration [570], Training MSE 0.0437836; Validation MSE 0.0189869
# Iteration [580], Training MSE 0.0437790; Validation MSE 0.0189899
# Iteration [590], Training MSE 0.0437745; Validation MSE 0.0189924
# Iteration [600], Training MSE 0.0437700; Validation MSE 0.0189943
# Iteration [610], Training MSE 0.0437657; Validation MSE 0.0189959
# Iteration [620], Training MSE 0.0437615; Validation MSE 0.0189969
# Iteration [630], Training MSE 0.0437572; Validation MSE 0.0189977
# Iteration [640], Training MSE 0.0437531; Validation MSE 0.0189980
# Iteration [650], Training MSE 0.0437489; Validation MSE 0.0189981
# Iteration [660], Training MSE 0.0437448; Validation MSE 0.0189978
# Iteration [670], Training MSE 0.0437407; Validation MSE 0.0189974
# Iteration [680], Training MSE 0.0437365; Validation MSE 0.0189967
# Iteration [690], Training MSE 0.0437324; Validation MSE 0.0189958
# Iteration [700], Training MSE 0.0437283; Validation MSE 0.0189947
# Iteration [710], Training MSE 0.0437242; Validation MSE 0.0189934
# Iteration [720], Training MSE 0.0437201; Validation MSE 0.0189920
# Iteration [730], Training MSE 0.0437160; Validation MSE 0.0189904
# Iteration [740], Training MSE 0.0437119; Validation MSE 0.0189888
# Iteration [750], Training MSE 0.0437078; Validation MSE 0.0189870
# Iteration [760], Training MSE 0.0437037; Validation MSE 0.0189851
# Iteration [770], Training MSE 0.0436997; Validation MSE 0.0189831
# Iteration [780], Training MSE 0.0436956; Validation MSE 0.0189810
# Iteration [790], Training MSE 0.0436916; Validation MSE 0.0189789
# Iteration [800], Training MSE 0.0436875; Validation MSE 0.0189766
# Iteration [810], Training MSE 0.0436834; Validation MSE 0.0189743
# Iteration [820], Training MSE 0.0436794; Validation MSE 0.0189720
# Iteration [830], Training MSE 0.0436754; Validation MSE 0.0189696
# Iteration [840], Training MSE 0.0436714; Validation MSE 0.0189671
# Iteration [850], Training MSE 0.0436673; Validation MSE 0.0189645
# Iteration [860], Training MSE 0.0436633; Validation MSE 0.0189620
# Iteration [870], Training MSE 0.0436593; Validation MSE 0.0189594
# Iteration [880], Training MSE 0.0436553; Validation MSE 0.0189567
# Iteration [890], Training MSE 0.0436513; Validation MSE 0.0189540
# Iteration [900], Training MSE 0.0436474; Validation MSE 0.0189512
# Iteration [910], Training MSE 0.0436434; Validation MSE 0.0189484
# Iteration [920], Training MSE 0.0436394; Validation MSE 0.0189456
# Iteration [930], Training MSE 0.0436355; Validation MSE 0.0189427
# Iteration [940], Training MSE 0.0436316; Validation MSE 0.0189399
# Iteration [950], Training MSE 0.0436276; Validation MSE 0.0189369
# Iteration [960], Training MSE 0.0436237; Validation MSE 0.0189340
# Iteration [970], Training MSE 0.0436199; Validation MSE 0.0189310
# Iteration [980], Training MSE 0.0436160; Validation MSE 0.0189280
# Iteration [990], Training MSE 0.0436122; Validation MSE 0.0189249
# time: 2min 31s

# %%
# clean = lambda x: np.squeeze(x[:, -1: ])
# pred_train = clean(pred_train)
# pred_val = clean(pred_val)
# pred_test = clean(pred_test)
y_test.shape
# Out:
# (160, 48, 1)
# time: 2.41 ms

# %%
plt.close()
plt.figure(figsize=(32,16))
plt.plot(np.squeeze(p_test))
plt.plot(np.squeeze(y_test[:,-1]))
plt.legend(["Test Prediction", "Test Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 938 ms

# %%
plt.close()
plt.figure(figsize=(32,16))
plt.plot(np.squeeze(p_train))
plt.plot(np.squeeze(y_train[:,-1]))
plt.legend(["Training Prediction", "Training Actual"])
plt.grid(True)
plt.show()
# Out:
# time: 1.16 s

# %%
plt.close()
plt.plot(np.log(hist["train"]))
plt.plot(np.log(hist["val"]))
plt.legend(["Log Training Loss", "Log Validation Loss"])
plt.show()
