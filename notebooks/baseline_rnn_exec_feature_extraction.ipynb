# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint

# %%
import sys
sys.path.extend(["../"])
from core.tools.data_import import *
from core.tools.time_series import *
from core.tools.visualize import *
from core.models.feature_extracting_rnn import *
from constants import *

# %%
# # Select a source of file.
# pprint(UNRATE_DIR)
# #file_dir_selected = input("Select Directory ")
# file_dir_selected = "GCE"

# %%
# Pre-processing Parameters
PERIODS = 1
ORDER = 1
LAGS = 36

# %%
df = load_dataset("/home/qinchenwang/AnnEconForecast/data/UNRATE.csv")
prepared_df = differencing(df, periods=PERIODS, order=ORDER)
prepared_df.head()
# Out:
# Dataset loaded.
# 	Index type: datetime64[ns]
# 	Data type: float64
#             UNRATE_period1_order1
# DATE
# 1948-01-01                    NaN
# 1948-02-01                    0.4
# 1948-03-01                    0.2
# 1948-04-01                   -0.1
# 1948-05-01                   -0.4

# %%
X_raw, y_raw = gen_supervised_sequence(
    prepared_df, LAGS, prepared_df.columns[0], sequential_label=False)
# Out:
# Total 812 observations generated.
# Note: shape format: (num_obs, time_steps, num_inputs/outputs)
# X shape = (812, 36, 1), y shape = (812, 1, 1)

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X_raw, y_raw,
    test_size=0.2,
    shuffle=False
)

(X_train, X_val,
 y_train, y_val) = train_test_split(
    X_train, y_train,
    test_size=0.2,
    shuffle=False
)

# %%
# # Expand dimension so it fits the RNN input place holder.
# # (Num_Sample, time_steps, 1)
# X_train = np.expand_dims(X_train, axis=-1)
# X_test = np.expand_dims(X_test, axis=-1)
# X_val = np.expand_dims(X_val, axis=-1)

# %%
# y_train = np.expand_dims(y_train, axis=-1)
# y_test = np.expand_dims(y_test, axis=-1)
# y_val = np.expand_dims(y_val, axis=-1)

# %%
# X_raw = X_raw.reshape(812, LAGS)
# y_raw = y_raw.reshape(812, LAGS)
# print(X_raw.shape, y_raw.shape)

# %%
print(f"Training and testing set generated,\
\nX_train shape: {X_train.shape}\
\ny_train shape: {y_train.shape}\
\nX_test shape: {X_test.shape}\
\ny_test shape: {y_test.shape}\
\nX_validation shape: {X_val.shape}\
\ny_validation shape: {y_val.shape}")
# Out:
# Training and testing set generated,
# X_train shape: (519, 36, 1)
# y_train shape: (519, 1, 1)
# X_test shape: (163, 36, 1)
# y_test shape: (163, 1, 1)
# X_validation shape: (130, 36, 1)
# y_validation shape: (130, 1, 1)

# %%
# One Sample
plt.figure(figsize=(15, 5))
plt.title("The last training sample")
plt.plot(X_train[0])
plt.plot(y_train[0], "-o")
plt.legend(["X", "y"])
plt.grid(True)
plt.show()

# %%
# Model Parameters
num_time_steps = LAGS
# Number of series used to predict. (including concurrent)
num_inputs = 1
num_outputs = 1
num_neurons = 64
# Number of output series
learning_rate = 0.03
epochs = 1500
# Training Settings
report_periods = epochs // 10

# %%
parameters = {
    "num_time_steps": LAGS,
    "num_inputs": 1,
    "num_outputs": 36,
    "num_neurons": 64,
    "learning_rate": 0.003
}

# %%
# model = ExtractingBaselineRnn(para=parameters, sequential_label=True)
# model.states.h

# %%
model = ExtractingBaselineRnn(para=parameters, sequential_label=True)
# Out:
# Model: loading parameters
# Building placeholders...
# Building core rnn...
# Building metrics and operations...

# %%
hist = {"train": [], "val": []}

saver = tf.train.Saver()

with tf.Session() as sess:
    saver.restore(sess, "../model.ckpt")
#     sess.run(model.init)
#     for e in range(epochs):
#         progbar(e, epochs-1, 0)
#         sess.run(model.train,
#                  feed_dict={model.X: X_train, model.y: X_train})
#         if True:
#             eval_loss = lambda pred, resp: model.loss.eval(
#                 feed_dict={model.X: pred, model.y: resp})
#             train_mse = eval_loss(X_train, X_train)
#             val_mse = eval_loss(X_val, X_val)
#             # based on training set
#             persist_mse = ((X_train[1:] - X_train[:-1])**2).mean(axis=None)
#             hist["train"].append(train_mse)
#             hist["val"].append(val_mse)
#             print(f"Iteration [{e}], Training MSE {train_mse:0.7f}; Validation MSE {val_mse:0.7f}; Persistence MSE {persist_mse:0.7f}")
    
    if model.SL:
        gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})[:,-1]
    else:
        gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})
    p_train = gen_pred(X_train)
    p_test = gen_pred(X_test)
    save_path = saver.save(sess, "../model.ckpt")
    gen_pred1 = lambda src: model.states.c.eval(feed_dict={model.X: src})
    train_states = gen_pred1(X_train)
    test_states = gen_pred1(X_test)
# Out:
# INFO:tensorflow:Restoring parameters from ../model.ckpt

# %%
# Visualize testing set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Testing Set Result")
plt.plot(np.squeeze(p_test[:,-1]))
plt.plot(np.squeeze(X_test[:,-1]))
plt.legend(["Test Prediction", "Test Actual"])
plt.grid(True)
plt.show()

# %%
# Visualize training set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Training Set Result")
if model.SL:
    plt.plot(np.squeeze(p_train[:,-1]), alpha=0.8)
    plt.plot(np.squeeze(X_train[:,-1]), alpha=0.8)
else:
    plt.plot(np.squeeze(p_train), alpha=0.8)
    plt.plot(np.squeeze(X_train), alpha=0.8)
plt.legend(["Training Prediction", "Training Actual"])
plt.grid(True)
plt.show()

# %%
plt.close()
plt.plot(np.log(hist["train"]))
plt.plot(np.log(hist["val"]))
plt.legend(["Log Training Loss", "Log Validation Loss"])
plt.show()

# %%
parameters = {
    "num_time_steps": 64,
    "num_inputs": 1,
    "num_outputs": 1,
    "num_neurons": 128,
    "learning_rate": 0.003
}
model = ExtractingBaselineRnn(para=parameters, sequential_label=True)

train_states = train_states.reshape(-1, 64, 1)
test_states = test_states.reshape(-1, 64, 1)
y_train = y_train.reshape(-1, 1, 1)
y_test = y_test.reshape(-1, 1, 1)
print(train_states.shape, test_states.shape)
# Out:
# Model: loading parameters
# Building placeholders...
# Building core rnn...
# Building metrics and operations...
# (519, 64, 1) (163, 64, 1)

# %%
model = ExtractingBaselineRnn(para=parameters, sequential_label=True)
# Out:
# Model: loading parameters
# Building placeholders...
# Building core rnn...
# Building metrics and operations...

# %%
hist["train"] = []
# corresponding states should be trained and recorded for the training set, don't have to make one for testing
saver = tf.train.Saver()
with tf.Session() as sess:
    sess.run(model.init)
    for e in range(epochs):
        progbar(e, epochs-1, 0)
        sess.run(model.train,
                 feed_dict={model.X: train_states, model.y: y_train})
        if True:
            eval_loss = lambda pred, resp: model.loss.eval(
                feed_dict={model.X: pred, model.y: resp})
            train_mse = eval_loss(train_states, y_train)
            # based on training set
            persist_mse = ((y_train[1:] - y_train[:-1])**2).mean(axis=None)
            hist["train"].append(train_mse)
            print(f"Iteration [{e}], Training MSE {train_mse:0.7f}; Persistence MSE {persist_mse:0.7f}")
    
    gen_pred = lambda src: model.outputs.eval(feed_dict={model.X: src})[:,-1]
    p_train = gen_pred(train_states)
    p_test = gen_pred(test_states)
    save_path = saver.save(sess, "../model_pred.ckpt")
# Out:
#   [0/1499,   0.00%]Iteration [0], Training MSE 0.0461990; Persistence MSE 0.0705792
#   [1/1499,   0.07%]Iteration [1], Training MSE 0.0438282; Persistence MSE 0.0705792
#   [2/1499,   0.13%]Iteration [2], Training MSE 0.0445316; Persistence MSE 0.0705792
#   [3/1499,   0.20%]Iteration [3], Training MSE 0.0446134; Persistence MSE 0.0705792
#   [4/1499,   0.27%]Iteration [4], Training MSE 0.0440992; Persistence MSE 0.0705792
#   [5/1499,   0.33%]Iteration [5], Training MSE 0.0437889; Persistence MSE 0.0705792
#   [6/1499,   0.40%]Iteration [6], Training MSE 0.0437554; Persistence MSE 0.0705792
#   [7/1499,   0.47%]Iteration [7], Training MSE 0.0438691; Persistence MSE 0.0705792
#   [8/1499,   0.53%]Iteration [8], Training MSE 0.0439747; Persistence MSE 0.0705792
#   [9/1499,   0.60%]Iteration [9], Training MSE 0.0439942; Persistence MSE 0.0705792
#   [10/1499,   0.67%]Iteration [10], Training MSE 0.0439354; Persistence MSE 0.0705792
#   [11/1499,   0.73%]Iteration [11], Training MSE 0.0438458; Persistence MSE 0.0705792
#   [12/1499,   0.80%]Iteration [12], Training MSE 0.0437722; Persistence MSE 0.0705792
#   [13/1499,   0.87%]Iteration [13], Training MSE 0.0437419; Persistence MSE 0.0705792
#   [14/1499,   0.93%]Iteration [14], Training MSE 0.0437566; Persistence MSE 0.0705792
#   [15/1499,   1.00%]Iteration [15], Training MSE 0.0437895; Persistence MSE 0.0705792
#   [16/1499,   1.07%]Iteration [16], Training MSE 0.0438092; Persistence MSE 0.0705792
#   [17/1499,   1.13%]Iteration [17], Training MSE 0.0438037; Persistence MSE 0.0705792
#   [18/1499,   1.20%]Iteration [18], Training MSE 0.0437785; Persistence MSE 0.0705792
#   [19/1499,   1.27%]Iteration [19], Training MSE 0.0437482; Persistence MSE 0.0705792
#   [20/1499,   1.33%]Iteration [20], Training MSE 0.0437258; Persistence MSE 0.0705792
#   [21/1499,   1.40%]Iteration [21], Training MSE 0.0437153; Persistence MSE 0.0705792
#   [22/1499,   1.47%]Iteration [22], Training MSE 0.0437149; Persistence MSE 0.0705792
#   [23/1499,   1.53%]Iteration [23], Training MSE 0.0437180; Persistence MSE 0.0705792
#   [24/1499,   1.60%]Iteration [24], Training MSE 0.0437181; Persistence MSE 0.0705792
#   [482/1499,  32.15%]Iteration [482], Training MSE 0.0453782; Persistence MSE 0.0705792
#   [483/1499,  32.22%]Iteration [483], Training MSE 0.0441828; Persistence MSE 0.0705792
#   [484/1499,  32.29%]Iteration [484], Training MSE 0.0419374; Persistence MSE 0.0705792
#   [485/1499,  32.35%]Iteration [485], Training MSE 0.0433320; Persistence MSE 0.0705792
#   [486/1499,  32.42%]Iteration [486], Training MSE 0.0420269; Persistence MSE 0.0705792
#   [487/1499,  32.49%]Iteration [487], Training MSE 0.0419819; Persistence MSE 0.0705792
#   [488/1499,  32.56%]Iteration [488], Training MSE 0.0425593; Persistence MSE 0.0705792
#   [489/1499,  32.62%]Iteration [489], Training MSE 0.0427961; Persistence MSE 0.0705792
#   [490/1499,  32.69%]Iteration [490], Training MSE 0.0427240; Persistence MSE 0.0705792
#   [491/1499,  32.76%]Iteration [491], Training MSE 0.0425048; Persistence MSE 0.0705792
#   [492/1499,  32.82%]Iteration [492], Training MSE 0.0423358; Persistence MSE 0.0705792
#   [493/1499,  32.89%]Iteration [493], Training MSE 0.0423436; Persistence MSE 0.0705792
#   [494/1499,  32.96%]Iteration [494], Training MSE 0.0425906; Persistence MSE 0.0705792
#   [495/1499,  33.02%]Iteration [495], Training MSE 0.0424551; Persistence MSE 0.0705792
#   [496/1499,  33.09%]Iteration [496], Training MSE 0.0421134; Persistence MSE 0.0705792
#   [497/1499,  33.16%]Iteration [497], Training MSE 0.0420629; Persistence MSE 0.0705792
#   [498/1499,  33.22%]Iteration [498], Training MSE 0.0420871; Persistence MSE 0.0705792
#   [499/1499,  33.29%]Iteration [499], Training MSE 0.0419893; Persistence MSE 0.0705792
#   [500/1499,  33.36%]Iteration [500], Training MSE 0.0416682; Persistence MSE 0.0705792
#   [501/1499,  33.42%]Iteration [501], Training MSE 0.0414960; Persistence MSE 0.0705792
#   [502/1499,  33.49%]Iteration [502], Training MSE 0.0416515; Persistence MSE 0.0705792
#   [503/1499,  33.56%]Iteration [503], Training MSE 0.0412176; Persistence MSE 0.0705792
#   [504/1499,  33.62%]Iteration [504], Training MSE 0.0413901; Persistence MSE 0.0705792
#   [505/1499,  33.69%]Iteration [505], Training MSE 0.0412476; Persistence MSE 0.0705792
#   [506/1499,  33.76%]Iteration [506], Training MSE 0.0410957; Persistence MSE 0.0705792
#   [507/1499,  33.82%]Iteration [507], Training MSE 0.0410928; Persistence MSE 0.0705792
#   [508/1499,  33.89%]Iteration [508], Training MSE 0.0410601; Persistence MSE 0.0705792
#   [509/1499,  33.96%]Iteration [509], Training MSE 0.0409466; Persistence MSE 0.0705792
#   [510/1499,  34.02%]Iteration [510], Training MSE 0.0410984; Persistence MSE 0.0705792
#   [511/1499,  34.09%]Iteration [511], Training MSE 0.0407851; Persistence MSE 0.0705792
#   [512/1499,  34.16%]Iteration [512], Training MSE 0.0407860; Persistence MSE 0.0705792
#   [513/1499,  34.22%]Iteration [513], Training MSE 0.0409272; Persistence MSE 0.0705792
#   [514/1499,  34.29%]Iteration [514], Training MSE 0.0409363; Persistence MSE 0.0705792
#   [1386/1499,  92.46%]Iteration [1386], Training MSE 0.0388694; Persistence MSE 0.0705792
#   [1387/1499,  92.53%]Iteration [1387], Training MSE 0.0383350; Persistence MSE 0.0705792
#   [1388/1499,  92.60%]Iteration [1388], Training MSE 0.0387802; Persistence MSE 0.0705792
#   [1389/1499,  92.66%]Iteration [1389], Training MSE 0.0390726; Persistence MSE 0.0705792
#   [1390/1499,  92.73%]Iteration [1390], Training MSE 0.0386378; Persistence MSE 0.0705792
#   [1391/1499,  92.80%]Iteration [1391], Training MSE 0.0388689; Persistence MSE 0.0705792
#   [1392/1499,  92.86%]Iteration [1392], Training MSE 0.0381577; Persistence MSE 0.0705792
#   [1393/1499,  92.93%]Iteration [1393], Training MSE 0.0379385; Persistence MSE 0.0705792
#   [1394/1499,  93.00%]Iteration [1394], Training MSE 0.0383860; Persistence MSE 0.0705792
#   [1395/1499,  93.06%]Iteration [1395], Training MSE 0.0381250; Persistence MSE 0.0705792
#   [1396/1499,  93.13%]Iteration [1396], Training MSE 0.0383538; Persistence MSE 0.0705792
#   [1397/1499,  93.20%]Iteration [1397], Training MSE 0.0384669; Persistence MSE 0.0705792
#   [1398/1499,  93.26%]Iteration [1398], Training MSE 0.0385370; Persistence MSE 0.0705792
#   [1399/1499,  93.33%]Iteration [1399], Training MSE 0.0383775; Persistence MSE 0.0705792
#   [1400/1499,  93.40%]Iteration [1400], Training MSE 0.0383563; Persistence MSE 0.0705792
#   [1401/1499,  93.46%]Iteration [1401], Training MSE 0.0380494; Persistence MSE 0.0705792
#   [1402/1499,  93.53%]Iteration [1402], Training MSE 0.0381991; Persistence MSE 0.0705792
#   [1403/1499,  93.60%]Iteration [1403], Training MSE 0.0381157; Persistence MSE 0.0705792
#   [1404/1499,  93.66%]Iteration [1404], Training MSE 0.0381486; Persistence MSE 0.0705792
#   [1405/1499,  93.73%]Iteration [1405], Training MSE 0.0378479; Persistence MSE 0.0705792
#   [1406/1499,  93.80%]Iteration [1406], Training MSE 0.0379220; Persistence MSE 0.0705792
#   [1407/1499,  93.86%]Iteration [1407], Training MSE 0.0381763; Persistence MSE 0.0705792
#   [1408/1499,  93.93%]Iteration [1408], Training MSE 0.0380124; Persistence MSE 0.0705792
#   [1409/1499,  94.00%]Iteration [1409], Training MSE 0.0381349; Persistence MSE 0.0705792
#   [1410/1499,  94.06%]Iteration [1410], Training MSE 0.0378430; Persistence MSE 0.0705792
#   [1411/1499,  94.13%]Iteration [1411], Training MSE 0.0383419; Persistence MSE 0.0705792
#   [1412/1499,  94.20%]Iteration [1412], Training MSE 0.0382403; Persistence MSE 0.0705792
#   [1413/1499,  94.26%]Iteration [1413], Training MSE 0.0379918; Persistence MSE 0.0705792
#   [1414/1499,  94.33%]Iteration [1414], Training MSE 0.0379605; Persistence MSE 0.0705792
#   [1415/1499,  94.40%]Iteration [1415], Training MSE 0.0382616; Persistence MSE 0.0705792
#   [1416/1499,  94.46%]Iteration [1416], Training MSE 0.0377913; Persistence MSE 0.0705792
#   [1417/1499,  94.53%]Iteration [1417], Training MSE 0.0379771; Persistence MSE 0.0705792
#   [1418/1499,  94.60%]Iteration [1418], Training MSE 0.0381518; Persistence MSE 0.0705792
#   [1419/1499,  94.66%]Iteration [1419], Training MSE 0.0378066; Persistence MSE 0.0705792
#   [1420/1499,  94.73%]Iteration [1420], Training MSE 0.0381295; Persistence MSE 0.0705792
#   [1421/1499,  94.80%]Iteration [1421], Training MSE 0.0376875; Persistence MSE 0.0705792
#   [1422/1499,  94.86%]Iteration [1422], Training MSE 0.0378899; Persistence MSE 0.0705792
#   [1423/1499,  94.93%]Iteration [1423], Training MSE 0.0382073; Persistence MSE 0.0705792
#   [1424/1499,  95.00%]Iteration [1424], Training MSE 0.0382428; Persistence MSE 0.0705792
#   [1425/1499,  95.06%]Iteration [1425], Training MSE 0.0378483; Persistence MSE 0.0705792
#   [1426/1499,  95.13%]Iteration [1426], Training MSE 0.0379037; Persistence MSE 0.0705792
#   [1427/1499,  95.20%]Iteration [1427], Training MSE 0.0385339; Persistence MSE 0.0705792
#   [1428/1499,  95.26%]Iteration [1428], Training MSE 0.0376836; Persistence MSE 0.0705792
#   [1429/1499,  95.33%]Iteration [1429], Training MSE 0.0390288; Persistence MSE 0.0705792
#   [1430/1499,  95.40%]Iteration [1430], Training MSE 0.0383799; Persistence MSE 0.0705792
#   [1431/1499,  95.46%]Iteration [1431], Training MSE 0.0381539; Persistence MSE 0.0705792
#   [1432/1499,  95.53%]Iteration [1432], Training MSE 0.0385407; Persistence MSE 0.0705792
#   [1433/1499,  95.60%]Iteration [1433], Training MSE 0.0378013; Persistence MSE 0.0705792
#   [1434/1499,  95.66%]Iteration [1434], Training MSE 0.0382402; Persistence MSE 0.0705792
#   [1435/1499,  95.73%]Iteration [1435], Training MSE 0.0376568; Persistence MSE 0.0705792
#   [1436/1499,  95.80%]Iteration [1436], Training MSE 0.0387636; Persistence MSE 0.0705792
#   [1437/1499,  95.86%]Iteration [1437], Training MSE 0.0378200; Persistence MSE 0.0705792
#   [1438/1499,  95.93%]Iteration [1438], Training MSE 0.0379159; Persistence MSE 0.0705792
#   [1439/1499,  96.00%]Iteration [1439], Training MSE 0.0381349; Persistence MSE 0.0705792
#   [1440/1499,  96.06%]Iteration [1440], Training MSE 0.0376305; Persistence MSE 0.0705792
#   [1441/1499,  96.13%]Iteration [1441], Training MSE 0.0379992; Persistence MSE 0.0705792
#   [1442/1499,  96.20%]Iteration [1442], Training MSE 0.0376227; Persistence MSE 0.0705792
#   [1443/1499,  96.26%]Iteration [1443], Training MSE 0.0378599; Persistence MSE 0.0705792
#   [1444/1499,  96.33%]Iteration [1444], Training MSE 0.0377316; Persistence MSE 0.0705792
#   [1445/1499,  96.40%]Iteration [1445], Training MSE 0.0375644; Persistence MSE 0.0705792
#   [1446/1499,  96.46%]Iteration [1446], Training MSE 0.0376539; Persistence MSE 0.0705792
#   [1447/1499,  96.53%]Iteration [1447], Training MSE 0.0379097; Persistence MSE 0.0705792
#   [1448/1499,  96.60%]Iteration [1448], Training MSE 0.0376084; Persistence MSE 0.0705792
#   [1480/1499,  98.73%]Iteration [1480], Training MSE 0.0375528; Persistence MSE 0.0705792
#   [1481/1499,  98.80%]Iteration [1481], Training MSE 0.0375087; Persistence MSE 0.0705792
#   [1482/1499,  98.87%]Iteration [1482], Training MSE 0.0376298; Persistence MSE 0.0705792
#   [1483/1499,  98.93%]Iteration [1483], Training MSE 0.0375716; Persistence MSE 0.0705792
#   [1484/1499,  99.00%]Iteration [1484], Training MSE 0.0374654; Persistence MSE 0.0705792
#   [1485/1499,  99.07%]Iteration [1485], Training MSE 0.0374929; Persistence MSE 0.0705792
#   [1486/1499,  99.13%]Iteration [1486], Training MSE 0.0375371; Persistence MSE 0.0705792
#   [1487/1499,  99.20%]Iteration [1487], Training MSE 0.0376054; Persistence MSE 0.0705792
#   [1488/1499,  99.27%]Iteration [1488], Training MSE 0.0379095; Persistence MSE 0.0705792
#   [1489/1499,  99.33%]Iteration [1489], Training MSE 0.0379997; Persistence MSE 0.0705792
#   [1490/1499,  99.40%]Iteration [1490], Training MSE 0.0374712; Persistence MSE 0.0705792
#   [1491/1499,  99.47%]Iteration [1491], Training MSE 0.0382535; Persistence MSE 0.0705792
#   [1492/1499,  99.53%]Iteration [1492], Training MSE 0.0383874; Persistence MSE 0.0705792
#   [1493/1499,  99.60%]Iteration [1493], Training MSE 0.0383489; Persistence MSE 0.0705792
#   [1494/1499,  99.67%]Iteration [1494], Training MSE 0.0377813; Persistence MSE 0.0705792
#   [1495/1499,  99.73%]Iteration [1495], Training MSE 0.0379963; Persistence MSE 0.0705792
#   [1496/1499,  99.80%]Iteration [1496], Training MSE 0.0385389; Persistence MSE 0.0705792
#   [1497/1499,  99.87%]Iteration [1497], Training MSE 0.0384073; Persistence MSE 0.0705792
#   [1498/1499,  99.93%]Iteration [1498], Training MSE 0.0388533; Persistence MSE 0.0705792
#   [1499/1499, 100.00%]Iteration [1499], Training MSE 0.0384098; Persistence MSE 0.0705792

# %%
# Visualize training set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Training Set Result")
plt.plot(np.squeeze(p_train[:,-1]), alpha=0.8)
plt.plot(np.squeeze(y_train[:,-1]), alpha=0.8)
plt.legend(["Training Prediction", "Training Actual"])
plt.grid(True)
plt.show()

# %%
# Visualize testing set result
plt.close()
plt.figure(figsize=(32,16))
plt.title("Testing Set Result")
#plt.plot(np.squeeze(p_test))
#plt.plot(np.squeeze(y_test[:,-1]))
plt.errorbar(list(range(len(p_test))), p_test, marker='o')
plt.errorbar(list(range(len(y_test[:, -1]))), y_test[:,-1], marker='o')
#plt.legend(["Test Prediction", "Test Actual"])
plt.grid(True)
plt.show()

# %%
# start with initial credibility
cred = 1000
for i in range(len(y_raw)):
    if y_raw[i][0] * pred[i][0] >= 0:
        # predicted the same sign
        cred += 1
    else:
        cred -= 1
print(cred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6b81aac06abd> in <module>()
#       1 # start with initial credibility
#       2 cred = 1000
# ----> 3 for i in range(len(y_raw)):
#       4     if y_raw[i][0] * pred[i][0] >= 0:
#       5         # predicted the same sign
#
# NameError: name 'y_raw' is not defined
